# %% [markdown]
# # Langzeit Scheduling

# %% [markdown]
# <b> Erkenntnisse: </b>
# - Job-Reihenfolge im Solver ist relevant

# %%
import json
import random
import numpy as np
import pandas as pd

# %%
import pulp

# %%
import utils.checker as check
import utils.presenter as show
import utils.schedule_interarrival as sit
import utils.schedule_solver__with_arrivals as ssv

# %%
pd.set_option('display.max_rows', 30)

# %%
# Datei laden
with open("data/jobshop_instances.json", "r", encoding="utf-8") as f:
    jobshop_instances = json.load(f)

instance =  jobshop_instances["instance ft10"]
show.print_jobs(instance)
# Out:
# job 0:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# job 1:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# job 2:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# job 3:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# job 4:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# job 5:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# job 6:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# job 7:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# job 8:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# job 9:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]

# %%
def add_jobs_to_dict(job_set_dict, new_instance, shuffle=False, seed=50):
    offset = len(job_set_dict)
    items = list(new_instance.items())

    if shuffle:
        random.seed(seed)
        random.shuffle(items)

    for i, (_, ops) in enumerate(items):
        job_name = f"Job_{offset + i:03d}"
        job_set_dict[job_name] = ops

# %%
def generate_jobs_for_days(day_numb: int, jobs_instance: dict):
    jssp_data = {}

    # Schritt 1: Ursprüngliche Instanz vervielfachen (geschätzt mit Puffer)
    for i in range(int(2.3 *day_numb)):
        shuffle = False if (i % 2 == 0) else True
        add_jobs_to_dict(jssp_data, jobs_instance, shuffle)

    # Schritt 2: Zwischenankunftszeiten berechnen
    mean_interarrival_time = sit.calculate_mean_interarrival_time(jssp_data)
    df_arrivals = sit.generate_job_arrivals_df_by_mean_interarrival_time(jssp_data, t_a=mean_interarrival_time)

    
    # Schritt 3a: Filter auf df_arrivals anwenden
    df_arrivals = df_arrivals[df_arrivals["Arrival"] <= (60 * 24 * day_numb)]
    df_arrivals

    # Schritt 3b: Nur die verbleibenden Job-IDs extrahieren
    valid_job_ids = set(df_arrivals["Job"])

    # Schritt 3c: jssp_data kürzen
    jssp_data = {job_id: ops for job_id, ops in jssp_data.items() if job_id in valid_job_ids}

    return jssp_data, df_arrivals

# %%
jssp_data, df_arrivals = generate_jobs_for_days(4, instance)
show.print_jobs(jssp_data)
# Out:
# Job_000:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_001:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_002:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_003:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_004:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_005:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_006:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_007:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_008:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_009:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_010:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_011:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_012:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_013:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_014:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_015:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_016:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_017:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_018:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_019:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_020:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_021:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_022:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_023:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_024:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_025:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_026:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_027:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_028:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_029:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_030:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_031:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_032:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_033:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_034:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_035:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_036:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_037:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_038:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_039:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_040:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_041:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_042:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_043:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_044:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_045:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_046:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_047:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_048:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_049:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_050:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_051:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_052:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_053:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_054:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_055:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_056:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_057:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_058:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_059:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_060:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_061:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_062:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_063:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_064:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_065:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_066:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_067:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_068:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_069:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_070:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_071:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_072:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_073:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_074:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_075:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_076:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_077:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_078:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_079:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_080:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_081:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_082:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_083:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_084:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_085:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_086:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_087:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_088:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]

# %%
df_arrivals
# Out:
#         Job  Arrival
# 0   Job_000     0.00
# 1   Job_001    84.93
# 2   Job_002   106.18
# 3   Job_003   148.31
# 4   Job_004   185.08
# ..      ...      ...
# 84  Job_084  5519.69
# 85  Job_085  5542.52
# 86  Job_086  5591.92
# 87  Job_087  5644.29
# 88  Job_088  5680.08
#
# [89 rows x 2 columns]

# %% [markdown]
# ## I) Globalen Makespan minimieren
# - Jobs werden nach Ankunftszeit sotiert (absteigend) da es bessere Resultate liefert

# %%
df_plan_global, makespan = ssv.solve_jssp_global_makespan(jssp_data, df_arrivals, solver_time_limit=3600, epsilon=0.06)
print(f"Makespan: {makespan} Minuten")
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 3600
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/5207911e8a8a4e1495f96184c20a7888-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/5207911e8a8a4e1495f96184c20a7888-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  5207911e8a8a4e1495f96184c20a7888-pulp has 79299 rows; 40051 cols; 236829 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79210 rows, 40051 cols, 236740 nonzeros  0s
# 40050 rows, 40051 cols, 119260 nonzeros  0s
# 40050 rows, 40051 cols, 119260 nonzeros  0s
#
# Solving MIP model with:
#    40050 rows
#    40051 cols (39160 binary, 0 integer, 0 implied int., 891 continuous)
#    119260 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   6277.08         inf                  inf        0      0      0         0     0.1s
#  R       0       0         0   0.00%   6277.08         27373.28          77.07%        0      0      0      1903     0.3s
#          0       0         0   0.00%   6292.140131     27373.28          77.01%     8201    517      0     14949     5.6s
#  L       0       0         0   0.00%   6292.140131     14022.53          55.13%     9384    487      0     18513    50.9s
#  L       0       0         0   0.00%   6292.140131     11624.18          45.87%     9384    236      0     23923    92.8s
#        302     299         2   0.00%   6292.140131     11624.18          45.87%     9386    236      2     41482    99.7s
#        571     564         4   0.00%   6292.140131     11624.18          45.87%     9924    368      4     48676   105.2s
#       1315    1298         8   0.00%   6292.140131     11624.18          45.87%     8709    404     17     62698   118.9s
#  L    1315    1297         8   0.00%   6292.140131     11381.77          44.72%     9090    469     30     63213   167.2s
#       1606    1587         9   0.00%   6292.140131     11381.77          44.72%     9091    469     31     84302   172.5s
#  L    1606    1586         9   0.00%   6292.140131     10842.93          41.97%     9360    523     43     85006   246.2s
#  L    1747    1717        14   0.00%   6292.140131     10628.75          40.80%     9676    577     62    106526   301.6s
#       2098    2055        21   0.00%   6292.140131     10628.75          40.80%     9682    577     74    127196   308.3s
#  L    2098    2054        21   0.00%   6292.140131     10600.09          40.64%     9657    643     85    128355   389.5s
#       2866    2818        23   0.00%   6292.140131     10600.09          40.64%     9659    643     90    156356   402.7s
#  L    2866    2817        23   0.00%   6292.140131     10365.23          39.30%     9795    513    102    156964   456.7s
#       3195    3143        24   0.00%   6292.140131     10365.23          39.30%     9796    513    107    181076   462.9s
#  L    3195    3142        24   0.00%   6292.140131     9828.39           35.98%     9908    589    126    182006   517.6s
#       4314    4255        27   0.00%   6292.140131     9828.39           35.98%     9911    589    133    216880   537.1s
#  L    4314    4254        27   0.00%   6292.140131     9004.99           30.13%     9980    665    145    217795   582.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#       4679    4615        29   0.00%   6292.140131     9004.99           30.13%     9982    665    152    246555   589.8s
#  L    4679    4614        29   0.00%   6292.140131     8826.39           28.71%    11046   1026    152    248005   640.9s
#       5379    5313        30   0.00%   6292.140131     8826.39           28.71%    11047   1026    153    416586   697.9s
#       5392    5312        31   0.00%   6292.140131     8826.39           28.71%    11274   1101    157    448510  1081.4s
#       5998    5926        33   0.00%   6292.140131     8826.39           28.71%    11276   1101    161    459101  1092.2s
#       6014    5925        34   0.00%   6292.140131     8826.39           28.71%    11350    542    166    498455  1828.0s
#  L    6130    6049        37   0.00%   6292.140131     8798.39           28.49%    10413    589    175    502574  2230.1s
#       8930    8842        41   0.00%   6292.140131     8798.39           28.49%    10417    589    182    564420  2279.4s
#  L    8930    8841        41   0.00%   6292.140131     8776.29           28.31%    10754    640    186    564930  2493.9s
#  L    9052    8951        47   0.00%   6292.140131     8772.87           28.28%    10412    689    197    596251  3274.6s
#       9211    9094        51   0.00%   6292.140131     8772.87           28.28%    10686    726    207    643464  3279.6s
#       9995    9879        55   0.00%   6292.140131     8772.87           28.28%    10690    726    212    655806  3295.5s
#  L    9996    9877        56   0.00%   6292.140131     8703.05           27.70%    10946    590    218    656420  3600.0s
#       9997    9878        57   0.00%   6292.140131     8703.05           27.70%    10946    590    218    682242  3600.0s
#
# Solving report
#   Model             5207911e8a8a4e1495f96184c20a7888-pulp
#   Status            Time limit reached
#   Primal bound      8703.05
#   Dual bound        6292.14013068
#   Gap               27.7% (tolerance: 0.01%)
#   P-D integral      1127.25147738
#   Solution status   feasible
#                     8703.05 (objective)
#                     0 (bound viol.)
#                     5.27355936697e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            3600.03 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 16
#   Nodes             9997
#   Repair LPs        1 (1 feasible; 1166 iterations)
#   LP iterations     682242 (total)
#                     0 (strong br.)
#                     32538 (separation)
#                     310082 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/5207911e8a8a4e1495f96184c20a7888-pulp.sol
# Makespan: 8703.05 Minuten

# %%
df = df_plan_global
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

check.check_all_constraints(df, jssp_data)
# Out:
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Job-Machinen-Reihenfolge (Reihenfolge der Operationen je Job) ist korrekt!
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
# True

# %%
print(f"Globale Makespan:{max(df.End)}")
# Out:
# Globale Makespan:8703.05

# %%
df_job_flow = (
    df.groupby("Job")
    .agg({"Arrival": "first", "Start": "min","End": "max"})
    .rename(columns={"Arrival": "Arrival Time", "Start": "Start", "End": "Completion Time"})
    .reset_index()
)
df_job_flow
# Out:
#         Job  Arrival Time    Start  Completion Time
# 0   Job_000          0.00     0.00           395.00
# 1   Job_001         84.93    84.93           594.93
# 2   Job_002        106.18   400.99           988.11
# 3   Job_003        148.31   492.05          1264.05
# 4   Job_004        185.08   785.11          1489.11
# ..      ...           ...      ...              ...
# 84  Job_084       5519.69  7610.03          8449.57
# 85  Job_085       5542.52  7655.15          8698.11
# 86  Job_086       5591.92  7749.27          8648.99
# 87  Job_087       5644.29  7624.09          8679.99
# 88  Job_088       5680.08  7555.09          8634.87
#
# [89 rows x 4 columns]

# %%
df.to_csv("data/030_schedule_by_global_makespane.csv", index = False)

# %% [markdown]
# ## II) Indivuelle Flowtimes minimieren
# Flowtime eines Jobs = "Ende der letzen Operation des Jobs" - "Ankunftszeit des Jobs"
#
# - Jobs werden nach Ankunftszeit sotiert (absteigend) da es bessere Resultate liefert

# %% [markdown]
# ### A) Ungewichtet

# %%
df_plan_2a, total = ssv.solve_jssp_individual_flowtime(jssp_data, df_arrivals, solver_time_limit=3600, epsilon=0.06)
print(f"Globale Makespan: {max(df_plan_2a.End)}")
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 3600
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/1bc252b379554ca0b4db90e7ca11d829-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/1bc252b379554ca0b4db90e7ca11d829-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  1bc252b379554ca0b4db90e7ca11d829-pulp has 79299 rows; 40139 cols; 236829 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79121 rows, 40050 cols, 236562 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
#
# Solving MIP model with:
#    39961 rows
#    40050 cols (39160 binary, 0 integer, 0 implied int., 890 continuous)
#    119082 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   297703.47       inf                  inf        0      0      0         0     0.1s
#  R       0       0         0   0.00%   297732.47       1236652.96        75.92%        0      0      0      2025     0.3s
#          0       0         0   0.00%   301710.382898   1236652.96        75.60%    11190   3160      0     17513     5.6s
#          0       0         0   0.00%   301932.869282   1236652.96        75.58%    11049   2728      0     28677    10.8s
#          0       0         0   0.00%   302064.059397   1236652.96        75.57%    11642   2816      0     39015    15.9s
#  L       0       0         0   0.00%   302080.475649   511100.16         40.90%    12059   2672      0     43566    74.7s
#        131     128         2   0.00%   302080.475649   511100.16         40.90%    10314   1127      2     70958    80.7s
#        260     255         3   0.00%   302150.309898   511100.16         40.88%    11353   1765      3    101536    98.6s
#  L     260     254         3   0.00%   302150.309898   509643.62         40.71%    11694   1606      3    105823   166.6s
#        406     399         4   0.00%   302150.309898   509643.62         40.71%    11695   1606      4    136885   172.9s
#        583     574         5   0.00%   302150.309898   509643.62         40.71%    11642   2551      5    157062   183.6s
8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#       7115    6910       103   0.00%   302150.309898   450406.42         32.92%     8149   1905    110    821162  2472.1s
#
# Restarting search from the root node
# Model after restart has 39961 rows, 40050 cols (39160 bin., 0 int., 0 impl., 890 cont.), and 119082 nonzeros
#
#       7115       0         0   0.00%   302150.309898   450406.42         32.92%     1905      0      0    821162  2472.2s
#       7115       0         0   0.00%   302150.309898   450406.42         32.92%     1905    848      0    826486  2473.8s
#       7115       0         0   0.00%   302150.309898   450406.42         32.92%    10144   3041      0    834953  2479.1s
#       7143       0         1   0.00%   302150.309898   450406.42         32.92%     9609   1138      1    845312  2484.9s
#       7233      99         7   0.05%   302150.309898   450406.42         32.92%    11297   3030      7    875202  2497.1s
#       7559     409        18   0.05%   302150.309898   450406.42         32.92%    11308   3030     18    888585  2506.7s
#       7623     409        19   0.05%   302150.309898   450406.42         32.92%    10967   1976     19    907286  2513.2s
#       7719     535        24   0.06%   302150.309898   450406.42         32.92%    10569   1626     24    916461  2518.4s
#       7822     639        31   0.25%   302150.309898   450406.42         32.92%    10363   2017     31    933076  2527.1s
#       7956     772        35   0.25%   302150.309898   450406.42         32.92%    10367   2017     35    945738  2532.8s
#       7978     771        36   0.25%   302150.309898   450406.42         32.92%    11169   1917     36    958152  2540.4s
#       8202    1002        43   0.25%   302209.896131   450406.42         32.90%    11176   1917     43    966054  2545.9s
#       9185    1979        46   0.25%   302209.896131   450406.42         32.90%    13583   2164     47    978353  2562.3s
#       9416    2136        51   0.25%   302209.896131   450406.42         32.90%    13026   2537     52    992671  2569.8s
#      10014    2792        54   0.25%   302209.896131   450406.42         32.90%    11705   2767     55    999986  2579.0s
#      10683    3459        55   0.25%   302209.896131   450406.42         32.90%    13585    881     57     1005k  2587.5s
#  L   10836    3605        58   0.25%   302209.896131   450152.9          32.87%     9139   1298     62     1009k  3043.9s
#      13878    6646        59   0.25%   302209.896131   450152.9          32.87%     9140   1298     63     1069k  3090.3s
#      13983    6748        61   0.25%   302209.896131   450152.9          32.87%    14054   2207     66     1127k  3600.1s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#      13983    6748        61   0.25%   302209.896131   450152.9          32.87%    14054   2207     66     1127k  3600.1s
#
# Solving report
#   Model             1bc252b379554ca0b4db90e7ca11d829-pulp
#   Status            Time limit reached
#   Primal bound      450152.9
#   Dual bound        302209.896131
#   Gap               32.87% (tolerance: 0.01%)
#   P-D integral      1254.88722317
#   Solution status   feasible
#                     450152.9 (objective)
#                     0 (bound viol.)
#                     6.37223131806e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            3600.09 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 13
#   Nodes             13983
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1127981 (total)
#                     0 (strong br.)
#                     162467 (separation)
#                     449769 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/1bc252b379554ca0b4db90e7ca11d829-pulp.sol
# Globale Makespan: 9677.71

# %%
df = df_plan_2a
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

check.check_all_constraints(df, jssp_data)
# Out:
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Job-Machinen-Reihenfolge (Reihenfolge der Operationen je Job) ist korrekt!
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
# True

# %%
df_job_flow = (
    df.groupby("Job")
    .agg({"Arrival": "first", "Start": "min","End": "max"})
    .rename(columns={"Arrival": "Arrival Time", "Start": "Start", "End": "Completion Time"})
    .reset_index()
)
df_job_flow
# Out:
#         Job  Arrival Time    Start  Completion Time
# 0   Job_000          0.00     0.00           395.00
# 1   Job_001         84.93    84.93           648.17
# 2   Job_002        106.18   107.06           869.01
# 3   Job_003        148.31   198.12          1075.47
# 4   Job_004        185.08   217.99           814.17
# ..      ...           ...      ...              ...
# 84  Job_084       5519.69  7913.57          9297.59
# 85  Job_085       5542.52  8169.69          9265.65
# 86  Job_086       5591.92  8070.63          9126.41
# 87  Job_087       5644.29  8638.11          9567.65
# 88  Job_088       5680.08  8522.05          9677.71
#
# [89 rows x 4 columns]

# %%
df.to_csv("data/03a_schedule_by_individual_flowtime.csv", index = False)

# %% [markdown]
# ### B) Gewichtet (wenn früher arrival)

# %%
df_plan_2b, total = ssv.solve_jssp_weighted_individual_flowtime(jssp_data, df_arrivals, solver_time_limit=3600, epsilon=0.06)
print(f"Globale Makespan:{max(df_plan_2b.End)}")
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 3600
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/10f604a49d9149a48846c17a563d10a4-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/10f604a49d9149a48846c17a563d10a4-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  10f604a49d9149a48846c17a563d10a4-pulp has 79299 rows; 40139 cols; 236829 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [2e-04, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79121 rows, 40050 cols, 236562 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
#
# Solving MIP model with:
#    39961 rows
#    40050 cols (39160 binary, 0 integer, 0 implied int., 890 continuous)
#    119082 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   501.2321563     inf                  inf        0      0      0         0     0.1s
#  R       0       0         0   0.00%   530.2321563     903.2769223       41.30%        0      0      0      2211     0.3s
#          0       0         0   0.00%   533.6460546     903.2769223       40.92%    11117   2984      0     20333     5.4s
#          0       0         0   0.00%   534.2692533     903.2769223       40.85%    13354   3973      0     36401    11.6s
#          0       0         0   0.00%   534.4408507     903.2769223       40.83%    11505   3329      0     51705    17.5s
#          0       0         0   0.00%   534.57014       903.2769223       40.82%    11587   2392      0     68050    24.1s
#          0       0         0   0.00%   534.6150005     903.2769223       40.81%    12404   2677      0     84030    29.6s
#          0       0         0   0.00%   534.6616797     903.2769223       40.81%    10966   2535      0     98622    35.6s
#          0       0         0   0.00%   534.720084      903.2769223       40.80%    13234   2492      0    120943    43.1s
#          0       0         0   0.00%   534.7481521     903.2769223       40.80%    11302   2910      0    139148    49.6s
#       4448    3507       107   0.00%   534.8464893     590.6345988        9.45%    10807   2064    136     2300k  2513.6s
#       4464    3511       111   0.00%   534.8464893     590.6345988        9.45%    10809   2064    138     2314k  2518.7s
#       4543    3604       116   0.00%   534.8464893     590.6345988        9.45%     9309   1751    141     2413k  3096.3s
#       4577    3606       119   0.00%   534.8464893     590.6345988        9.45%     9311   1751    143     2432k  3102.3s
#       4850    3908       123   0.00%   534.8464893     590.6345988        9.45%     9314   1751    146     2444k  3111.5s
#       4858    3908       124   0.00%   534.8464893     590.6345988        9.45%    12721   2211    147     2486k  3125.2s
#       5027    4077       127   0.00%   534.8464893     590.6345988        9.45%    12723   2211    149     2531k  3147.1s
#       5028    4077       128   0.00%   534.8464893     590.6345988        9.45%    11050   1413    150     2594k  3600.1s
#       5028    4077       128   0.00%   534.8464893     590.6345988        9.45%    11050   1413    150     2594k  3600.1s
#
# Solving report
#   Model             10f604a49d9149a48846c17a563d10a4-pulp
#   Status            Time limit reached
#   Primal bound      590.634598812
#   Dual bound        534.846489331
#   Gap               9.45% (tolerance: 0.01%)
#   P-D integral      434.122004748
#   Solution status   feasible
#                     590.634598812 (objective)
#                     0 (bound viol.)
#                     4.30766533555e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            3600.12 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 12
#   Nodes             5028
#   Repair LPs        3 (3 feasible; 3829 iterations)
#   LP iterations     2594947 (total)
#                     0 (strong br.)
#                     508202 (separation)
#                     957230 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/10f604a49d9149a48846c17a563d10a4-pulp.sol
# Globale Makespan:8991.64

# %%
df = df_plan_2b
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

check.check_all_constraints(df, jssp_data)
# Out:
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Job-Machinen-Reihenfolge (Reihenfolge der Operationen je Job) ist korrekt!
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
# True

# %%
print(f"Globale Makespan:{max(df.End)}")
# Out:
# Globale Makespan:8991.64

# %%
df_job_flow = (
    df.groupby("Job")
    .agg({"Arrival": "first", "Start": "min","End": "max"})
    .rename(columns={"Arrival": "Arrival Time", "Start": "Start", "End": "Completion Time"})
    .reset_index()
)
df_job_flow
# Out:
#         Job  Arrival Time    Start  Completion Time
# 0   Job_000          0.00     0.00           395.00
# 1   Job_001         84.93    84.93           644.12
# 2   Job_002        106.18   107.06           675.06
# 3   Job_003        148.31   198.12          1458.96
# 4   Job_004        185.08   217.99           807.18
# ..      ...           ...      ...              ...
# 84  Job_084       5519.69  7302.62          8392.34
# 85  Job_085       5542.52  7316.68          8766.52
# 86  Job_086       5591.92  7649.98          8623.40
# 87  Job_087       5644.29  7575.86          8881.58
# 88  Job_088       5680.08  7952.92          8991.64
#
# [89 rows x 4 columns]

# %%
df.to_csv("data/03b_schedule_by_individual_flowtime_weighted.csv", index = False)
