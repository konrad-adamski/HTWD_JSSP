# %% [markdown]
# # Simulation & Rescheduling nach einem Tag

# %%
import json
import pandas as pd
import numpy as np
import random

# %%
import utils.converter as convert
import utils.presenter as show
import utils.schedule_solver as ssv

# %%
from utils.checker import is_machine_conflict_free
from utils.checker import is_job_machine_sequence_correct
from utils.checker import is_start_correct

# %%
from ProductionDaySimulation import ProductionDaySimulation

# %%
df_plan = pd.read_csv("data/03b_schedule_by_individual_flowtime_weighted.csv")
df_plan = df_plan.sort_values(by=["Arrival", "Start"]).reset_index(drop=True)
df_plan
# Out:
#          Job  Arrival Machine    Start  Processing Time  Flow time      End
# 0    Job_000     0.00      M0     0.00               29      29.00    29.00
# 1    Job_000     0.00      M1    29.00               78     107.00   107.00
# 2    Job_000     0.00      M2   107.00                9     116.00   116.00
# 3    Job_000     0.00      M3   116.00               36     152.00   152.00
# 4    Job_000     0.00      M4   152.00               49     201.00   201.00
# ..       ...      ...     ...      ...              ...        ...      ...
# 885  Job_088  5680.08      M9  9250.94               11    3581.86  9261.94
# 886  Job_088  5680.08      M6  9261.94               40    3621.86  9301.94
# 887  Job_088  5680.08      M7  9301.94               89    3710.86  9390.94
# 888  Job_088  5680.08      M4  9390.94               26    3736.86  9416.94
# 889  Job_088  5680.08      M8  9416.94               74    3810.86  9490.94
#
# [890 rows x 7 columns]

# %%
jssp_data = convert.get_jssp_from_schedule(df_plan)
show.print_jobs(jssp_data)
# Out:
# Job_000:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_001:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_002:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_003:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_004:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_005:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_006:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_007:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_008:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_009:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_010:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_011:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_012:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_013:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_014:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_015:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_016:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_017:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_018:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_019:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_020:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_021:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_022:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_023:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_024:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_025:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_026:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_027:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_028:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_029:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_030:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_031:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_032:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_033:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_034:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_035:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_036:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_037:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_038:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_039:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_040:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_041:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_042:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_043:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_044:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_045:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_046:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_047:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_048:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_049:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_050:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_051:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_052:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_053:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_054:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_055:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_056:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_057:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_058:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_059:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_060:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_061:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_062:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_063:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_064:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_065:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_066:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_067:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_068:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_069:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_070:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_071:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_072:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_073:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_074:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_075:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_076:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_077:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_078:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_079:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_080:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_081:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_082:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_083:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_084:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_085:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_086:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_087:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_088:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]

# %% [markdown]
# ## First Day

# %%
day_start = 0
day_end = 1440

filt = (df_plan["Arrival"] >=  day_start) & (df_plan["Start"] < day_end)
df_schedule_first_day = df_plan[filt]
df_schedule_first_day
# Out:
#          Job  Arrival Machine    Start  Processing Time  Flow time      End
# 0    Job_000     0.00      M0     0.00               29      29.00    29.00
# 1    Job_000     0.00      M1    29.00               78     107.00   107.00
# 2    Job_000     0.00      M2   107.00                9     116.00   116.00
# 3    Job_000     0.00      M3   116.00               36     152.00   152.00
# 4    Job_000     0.00      M4   152.00               49     201.00   201.00
# ..       ...      ...     ...      ...              ...        ...      ...
# 191  Job_019   843.88      M0  1274.02               86     516.14  1360.02
# 192  Job_019   843.88      M1  1360.02               46     562.14  1406.02
# 200  Job_020   972.75      M0  1360.08               29     416.33  1389.08
# 201  Job_020   972.75      M1  1406.08               78     511.33  1484.08
# 210  Job_021  1013.15      M0  1389.14               43     418.99  1432.14
#
# [161 rows x 7 columns]

# %%
simulation = ProductionDaySimulation(df_schedule_first_day, vc=0.25)
df_execution, df_undone = simulation.run(end_time=day_end)
# Out:
# [00:00:00] Job_000 started on M0
# [00:28:42] Job_000 finished on M0 (after 28 minutes 43 seconds)
# [00:29:00] Job_000 started on M1
# [01:24:55] Job_001 started on M0
# [01:53:31] Job_000 finished on M1 (after 84 minutes 31 seconds)
# [01:53:31] Job_002 started on M1
# [01:53:31] Job_000 started on M2
# [01:58:43] Job_000 finished on M2 (after 05 minutes 13 seconds)
# [01:58:43] Job_000 started on M3
# [02:05:30] Job_001 finished on M0 (after 40 minutes 35 seconds)
# [02:07:55] Job_001 started on M2
# [02:25:44] Job_000 finished on M3 (after 27 minutes 01 second)
# [02:32:00] Job_000 started on M4
# [02:58:56] Job_002 finished on M1 (after 65 minutes 25 seconds)
# [03:14:57] Job_000 finished on M4 (after 42 minutes 58 seconds)
# [03:18:03] Job_002 started on M0
# [03:18:07] Job_003 started on M1
# [03:21:00] Job_000 started on M5
# [03:28:59] Job_000 finished on M5 (after 07 minutes 59 seconds)
# [03:32:00] Job_000 started on M6
# [04:08:39] Job_001 finished on M2 (after 120 minutes 44 seconds)
# [04:08:39] Job_004 started on M2
# [04:08:39] Job_001 started on M4
# [04:17:45] Job_004 finished on M2 (after 09 minutes 05 seconds)
# [04:46:38] Job_000 finished on M6 (after 74 minutes 39 seconds)
# [04:46:38] Job_000 started on M7
# [04:47:27] Job_002 finished on M0 (after 89 minutes 24 seconds)
# [04:47:27] Job_004 started on M0
# [04:47:27] Job_002 started on M3
# [04:53:38] Job_004 finished on M0 (after 06 minutes 11 seconds)
# [04:59:46] Job_003 finished on M1 (after 101 minutes 40 seconds)
# [04:59:46] Job_004 started on M1
# [05:20:51] Job_004 finished on M1 (after 21 minutes 05 seconds)
# [05:20:51] Job_006 started on M1
# [05:20:51] Job_004 started on M5
# [05:22:35] Job_001 finished on M4 (after 73 minutes 56 seconds)
# [05:22:35] Job_001 started on M9
# [05:33:23] Job_000 finished on M7 (after 46 minutes 44 seconds)
# [05:33:23] Job_000 started on M8
# [05:35:42] Job_001 finished on M9 (after 13 minutes 07 seconds)
# [05:40:29] Job_002 finished on M3 (after 53 minutes 02 seconds)
# [05:40:29] Job_001 started on M3
# [05:40:29] Job_002 started on M2
# [05:44:18] Job_008 started on M0
# [06:10:28] Job_000 finished on M8 (after 37 minutes 05 seconds)
# [06:14:00] Job_000 started on M9
# [06:20:42] Job_006 finished on M1 (after 59 minutes 51 seconds)
# [06:28:44] Job_000 finished on M9 (after 14 minutes 44 seconds)
# [06:30:19] Job_004 finished on M5 (after 69 minutes 28 seconds)
# [06:50:31] Job_001 finished on M3 (after 70 minutes 02 seconds)
# [06:50:31] Job_004 started on M3
# [06:50:31] Job_001 started on M1
# [07:05:22] Job_008 finished on M0 (after 81 minutes 04 seconds)
# [07:05:22] Job_006 started on M0
# [07:15:31] Job_002 finished on M2 (after 95 minutes 02 seconds)
# [07:15:31] Job_005 started on M2
# [07:15:31] Job_002 started on M8
# [07:18:53] Job_001 finished on M1 (after 28 minutes 23 seconds)
# [07:18:53] Job_008 started on M1
# [07:18:53] Job_001 started on M6
# [07:31:06] Job_004 finished on M3 (after 40 minutes 35 seconds)
# [07:31:06] Job_004 started on M4
# [07:39:46] Job_006 finished on M0 (after 34 minutes 24 seconds)
# [07:39:46] Job_006 started on M3
# [07:53:49] Job_010 started on M0
# [08:07:46] Job_001 finished on M6 (after 48 minutes 53 seconds)
# [08:07:46] Job_001 started on M5
# [08:29:56] Job_006 finished on M3 (after 50 minutes 10 seconds)
# [08:37:16] Job_004 finished on M4 (after 66 minutes 10 seconds)
# [08:53:31] Job_008 finished on M1 (after 94 minutes 38 seconds)
# [08:53:31] Job_009 started on M1
# [08:53:31] Job_008 started on M3
# [08:58:56] Job_002 finished on M8 (after 103 minutes 25 seconds)
# [08:59:49] Job_001 finished on M5 (after 52 minutes 02 seconds)
# [08:59:49] Job_002 started on M5
# [08:59:49] Job_001 started on M7
# [09:02:40] Job_010 finished on M0 (after 68 minutes 52 seconds)
# [09:11:27] Job_002 finished on M5 (after 11 minutes 38 seconds)
# [09:28:49] Job_005 finished on M2 (after 133 minutes 18 seconds)
# [09:28:49] Job_003 started on M2
# [09:34:56] Job_008 finished on M3 (after 41 minutes 25 seconds)
# [09:49:28] Job_012 started on M0
# [10:14:27] Job_012 finished on M0 (after 24 minutes 59 seconds)
# [10:25:37] Job_001 finished on M7 (after 85 minutes 48 seconds)
# [10:25:37] Job_002 started on M7
# [10:25:37] Job_001 started on M8
# [10:34:43] Job_009 finished on M1 (after 101 minutes 12 seconds)
# [10:34:43] Job_005 started on M1
# [10:34:43] Job_009 started on M0
# [10:37:49] Job_002 finished on M7 (after 12 minutes 13 seconds)
# [10:37:49] Job_002 started on M6
# [10:37:58] Job_005 finished on M1 (after 03 minutes 15 seconds)
# [10:37:58] Job_011 started on M1
# [10:37:58] Job_005 started on M5
# [10:51:28] Job_001 finished on M8 (after 25 minutes 51 seconds)
# [10:51:28] Job_004 started on M8
# [10:52:45] Job_003 finished on M2 (after 83 minutes 56 seconds)
# [10:52:45] Job_006 started on M2
# [10:52:51] Job_009 finished on M0 (after 18 minutes 07 seconds)
# [10:52:51] Job_003 started on M0
# [11:08:50] Job_006 finished on M2 (after 16 minutes 05 seconds)
# [11:08:50] Job_007 started on M2
# [11:13:58] Job_004 finished on M8 (after 22 minutes 31 seconds)
# [11:13:58] Job_004 started on M7
# [11:18:53] Job_011 finished on M1 (after 40 minutes 55 seconds)
# [11:18:53] Job_010 started on M1
# [11:32:33] Job_007 finished on M2 (after 23 minutes 43 seconds)
# [11:32:33] Job_009 started on M2
# [11:34:19] Job_005 finished on M5 (after 56 minutes 20 seconds)
# [11:34:19] Job_008 started on M5
# [11:34:19] Job_005 started on M3
# [11:58:13] Job_004 finished on M7 (after 44 minutes 15 seconds)
# [12:00:58] Job_003 finished on M0 (after 68 minutes 07 seconds)
# [12:00:58] Job_011 started on M0
# [12:19:00] Job_002 finished on M6 (after 101 minutes 11 seconds)
# [12:19:00] Job_006 started on M6
# [12:19:00] Job_002 started on M9
# [12:27:20] Job_008 finished on M5 (after 53 minutes 01 second)
# [12:36:00] Job_005 finished on M3 (after 61 minutes 41 seconds)
# [12:36:00] Job_005 started on M8
# [12:43:10] Job_006 finished on M6 (after 24 minutes 10 seconds)
# [12:43:10] Job_006 started on M5
# [12:47:38] Job_011 finished on M0 (after 46 minutes 41 seconds)
# [12:47:38] Job_007 started on M0
# [12:47:38] Job_011 started on M3
# [12:51:36] Job_009 finished on M2 (after 79 minutes 03 seconds)
# [12:51:36] Job_008 started on M2
# [12:51:36] Job_009 started on M6
# [12:51:58] Job_002 finished on M9 (after 32 minutes 58 seconds)
# [12:51:58] Job_004 started on M9
# [12:51:58] Job_002 started on M4
# [12:55:00] Job_010 finished on M1 (after 96 minutes 07 seconds)
# [12:55:00] Job_012 started on M1
# [12:59:32] Job_006 finished on M5 (after 16 minutes 22 seconds)
# [12:59:33] Job_009 finished on M6 (after 07 minutes 57 seconds)
# [13:28:13] Job_005 finished on M8 (after 52 minutes 13 seconds)
# [13:34:43] Job_002 finished on M4 (after 42 minutes 45 seconds)
# [13:34:43] Job_003 started on M4
# [13:41:44] Job_004 finished on M9 (after 49 minutes 46 seconds)
# [13:41:44] Job_006 started on M9
# [13:46:21] Job_004 started on M6
# [13:46:36] Job_009 started on M8
# [13:52:13] Job_008 finished on M2 (after 60 minutes 37 seconds)
# [13:52:13] Job_017 started on M2
# [14:01:32] Job_007 finished on M0 (after 73 minutes 53 seconds)
# [14:01:32] Job_015 started on M0
# [14:05:24] Job_012 finished on M1 (after 70 minutes 25 seconds)
# [14:05:24] Job_013 started on M1
# [14:13:25] Job_006 finished on M9 (after 31 minutes 41 seconds)
# [14:13:25] Job_005 started on M9
# [14:15:53] Job_011 finished on M3 (after 88 minutes 15 seconds)
# [14:15:53] Job_010 started on M3
# [14:47:13] Job_004 finished on M6 (after 60 minutes 52 seconds)
# [14:53:50] Job_015 finished on M0 (after 52 minutes 18 seconds)
# [14:59:43] Job_009 finished on M8 (after 73 minutes 07 seconds)
# [14:59:43] Job_006 started on M8
# [15:06:18] Job_017 finished on M2 (after 74 minutes 05 seconds)
# [15:06:18] Job_012 started on M2
# [15:14:49] Job_012 finished on M2 (after 08 minutes 31 seconds)
# [15:14:49] Job_011 started on M2
# [15:22:56] Job_003 finished on M4 (after 108 minutes 13 seconds)
# [15:22:56] Job_003 started on M6
# [15:26:31] Job_011 finished on M2 (after 11 minutes 43 seconds)
# [15:26:31] Job_015 started on M2
# [15:28:48] Job_003 finished on M6 (after 05 minutes 52 seconds)
# [15:45:05] Job_010 finished on M3 (after 89 minutes 11 seconds)
# [15:45:05] Job_012 started on M3
# [15:45:05] Job_010 started on M5
# [15:47:42] Job_013 finished on M1 (after 102 minutes 18 seconds)
# [15:47:42] Job_007 started on M1
# [15:49:32] Job_011 started on M6
# [16:02:43] Job_005 finished on M9 (after 109 minutes 18 seconds)
# [16:02:43] Job_008 started on M9
# [16:02:43] Job_005 started on M0
# [16:08:06] Job_008 finished on M9 (after 05 minutes 23 seconds)
# [16:08:06] Job_009 started on M9
# [16:17:16] Job_010 finished on M5 (after 32 minutes 11 seconds)
# [16:20:01] Job_011 finished on M6 (after 30 minutes 29 seconds)
# [16:20:01] Job_008 started on M6
# [16:21:32] Job_011 started on M5
# [16:30:47] Job_012 finished on M3 (after 45 minutes 42 seconds)
# [16:30:47] Job_012 started on M4
# [16:39:09] Job_007 finished on M1 (after 51 minutes 27 seconds)
# [16:39:09] Job_014 started on M1
# [16:43:10] Job_011 finished on M5 (after 21 minutes 38 seconds)
# [16:46:12] Job_006 finished on M8 (after 106 minutes 29 seconds)
# [16:46:12] Job_003 started on M8
# [16:46:12] Job_006 started on M7
# [16:46:24] Job_015 finished on M2 (after 79 minutes 53 seconds)
# [16:46:24] Job_018 started on M2
# [16:50:19] Job_008 finished on M6 (after 30 minutes 17 seconds)
# [16:57:37] Job_005 finished on M0 (after 54 minutes 54 seconds)
# [16:57:37] Job_013 started on M0
# [16:57:37] Job_005 started on M6
# [17:02:36] Job_018 finished on M2 (after 16 minutes 11 seconds)
# [17:02:36] Job_010 started on M2
# [17:10:17] Job_006 finished on M7 (after 24 minutes 05 seconds)
# [17:10:17] Job_008 started on M7
# [17:16:52] Job_009 finished on M9 (after 68 minutes 46 seconds)
# [17:16:52] Job_011 started on M9
# [17:17:06] Job_012 finished on M4 (after 46 minutes 19 seconds)
# [17:17:06] Job_006 started on M4
# [17:17:06] Job_012 started on M5
# [17:26:00] Job_014 finished on M1 (after 46 minutes 51 seconds)
# [17:26:00] Job_016 started on M1
# [17:28:33] Job_012 finished on M5 (after 11 minutes 27 seconds)
# [17:40:45] Job_003 finished on M8 (after 54 minutes 33 seconds)
# [17:54:25] Job_005 finished on M6 (after 56 minutes 49 seconds)
# [17:54:25] Job_012 started on M6
# [17:57:50] Job_007 started on M5
# [18:07:59] Job_011 finished on M9 (after 51 minutes 07 seconds)
# [18:07:59] Job_011 started on M8
# [18:12:55] Job_013 finished on M0 (after 75 minutes 18 seconds)
# [18:12:55] Job_018 started on M0
# [18:12:55] Job_013 started on M3
# [18:17:48] Job_010 finished on M2 (after 75 minutes 13 seconds)
# [18:17:48] Job_014 started on M2
# [18:17:48] Job_010 started on M9
# [18:20:32] Job_018 finished on M0 (after 07 minutes 37 seconds)
# [18:26:09] Job_006 finished on M4 (after 69 minutes 03 seconds)
# [18:26:09] Job_015 started on M4
# [18:28:28] Job_010 finished on M9 (after 10 minutes 40 seconds)
# [18:29:54] Job_008 finished on M7 (after 79 minutes 37 seconds)
# [18:29:54] Job_003 started on M7
# [18:44:04] Job_013 finished on M3 (after 31 minutes 10 seconds)
# [18:45:15] Job_016 finished on M1 (after 79 minutes 14 seconds)
# [18:45:15] Job_018 started on M1
# [18:52:31] Job_012 finished on M6 (after 58 minutes 05 seconds)
# [19:00:03] Job_018 finished on M1 (after 14 minutes 49 seconds)
# [19:09:54] Job_017 started on M1
# [19:11:36] Job_017 finished on M1 (after 01 minute 42 seconds)
# [19:19:52] Job_007 finished on M5 (after 82 minutes 02 seconds)
# [19:19:52] Job_018 started on M5
# [19:43:42] Job_015 finished on M4 (after 77 minutes 33 seconds)
# [19:43:42] Job_005 started on M4
# [19:43:42] Job_015 started on M9
# [19:50:38] Job_005 finished on M4 (after 06 minutes 56 seconds)
# [19:50:38] Job_008 started on M4
# [19:52:28] Job_015 finished on M9 (after 08 minutes 46 seconds)
# [19:52:28] Job_015 started on M3
# [20:01:49] Job_014 finished on M2 (after 104 minutes 01 second)
# [20:01:49] Job_013 started on M2
# [20:01:49] Job_014 started on M0
# [20:02:41] Job_018 finished on M5 (after 42 minutes 49 seconds)
# [20:02:41] Job_017 started on M5
# [20:09:26] Job_003 finished on M7 (after 99 minutes 32 seconds)
# [20:09:26] Job_012 started on M7
# [20:09:49] Job_011 finished on M8 (after 121 minutes 50 seconds)
# [20:25:30] Job_008 finished on M4 (after 34 minutes 52 seconds)
# [20:25:30] Job_007 started on M4
# [20:39:47] Job_017 finished on M5 (after 37 minutes 07 seconds)
# [20:39:47] Job_009 started on M5
# [20:52:03] Job_015 finished on M3 (after 59 minutes 35 seconds)
# [20:52:03] Job_018 started on M3
# [20:52:03] Job_015 started on M1
# [20:56:07] Job_007 finished on M4 (after 30 minutes 37 seconds)
# [20:56:07] Job_007 started on M6
# [20:58:07] Job_013 finished on M2 (after 56 minutes 18 seconds)
# [20:58:07] Job_019 started on M2
# [20:58:07] Job_013 started on M8
# [21:00:16] Job_014 finished on M0 (after 58 minutes 27 seconds)
# [21:00:16] Job_016 started on M0
# [21:07:47] Job_012 finished on M7 (after 58 minutes 22 seconds)
# [21:07:47] Job_005 started on M7
# [21:15:16] Job_016 finished on M0 (after 15 minutes 01 second)
# [21:15:58] Job_019 finished on M2 (after 17 minutes 51 seconds)
# [21:15:58] Job_016 started on M2
# [21:15:58] Job_019 started on M0
# [21:20:20] Job_018 finished on M3 (after 28 minutes 17 seconds)
# [21:20:20] Job_003 started on M3
# [21:20:20] Job_018 started on M4
# [21:32:41] Job_015 finished on M1 (after 40 minutes 38 seconds)
# [21:33:44] Job_005 finished on M7 (after 25 minutes 57 seconds)
# [21:33:44] Job_011 started on M7
# [21:44:59] Job_009 finished on M5 (after 65 minutes 11 seconds)
# [21:54:01] Job_011 finished on M7 (after 20 minutes 17 seconds)
# [22:07:24] Job_016 finished on M2 (after 51 minutes 26 seconds)
# [22:17:32] Job_007 finished on M6 (after 81 minutes 25 seconds)
# [22:22:54] Job_010 started on M6
# [22:23:55] Job_019 finished on M0 (after 67 minutes 57 seconds)
# [22:36:04] Job_013 finished on M8 (after 97 minutes 57 seconds)
# [22:36:04] Job_012 started on M8
# [22:39:05] Job_018 finished on M4 (after 78 minutes 45 seconds)
# [22:39:05] Job_014 started on M4
# [22:40:01] Job_019 started on M1
# [22:40:04] Job_020 started on M0
# [22:47:06] Job_003 finished on M3 (after 86 minutes 46 seconds)
# [22:47:06] Job_017 started on M3
# [22:47:06] Job_003 started on M9
# [22:51:19] Job_010 finished on M6 (after 28 minutes 25 seconds)
# [22:57:04] Job_013 started on M5
# [23:02:54] Job_010 started on M7
# [23:02:57] Job_015 started on M6
# [23:08:15] Job_013 finished on M5 (after 11 minutes 11 seconds)
# [23:18:27] Job_020 finished on M0 (after 38 minutes 23 seconds)
# [23:18:27] Job_021 started on M0
# [23:19:20] Job_003 finished on M9 (after 32 minutes 14 seconds)
# [23:19:20] Job_003 started on M5
# [23:19:41] Job_019 finished on M1 (after 39 minutes 40 seconds)
# [23:22:33] Job_012 finished on M8 (after 46 minutes 29 seconds)
# [23:22:33] Job_008 started on M8
# [23:22:33] Job_012 started on M9
# [23:26:04] Job_020 started on M1
# [23:44:05] Job_012 finished on M9 (after 21 minutes 32 seconds)
# [23:51:25] Job_021 finished on M0 (after 32 minutes 58 seconds)
# [23:58:41] Job_014 finished on M4 (after 79 minutes 35 seconds)
# [23:58:41] Job_011 started on M4
# [24:01:38] Job_015 finished on M6 (after 58 minutes 41 seconds)
# [24:01:38] Job_016 interrupted before machine M6 — would start too late (after 24:00:00)
# [24:14:43] Job_017 finished on M3 (after 87 minutes 37 seconds)
# [24:14:43] Job_009 interrupted before machine M3 — would start too late (after 24:00:00)
# [24:17:40] Job_010 finished on M7 (after 74 minutes 46 seconds)
# [24:19:32] Job_003 finished on M5 (after 60 minutes 13 seconds)
# [24:19:32] Job_015 interrupted before machine M5 — would start too late (after 24:00:00)
# [24:40:37] Job_011 finished on M4 (after 41 minutes 56 seconds)
# [24:42:13] Job_020 finished on M1 (after 76 minutes 08 seconds)
# [25:00:17] Job_008 finished on M8 (after 97 minutes 44 seconds)
#
# [25:00:17] Simulation ended! There are no more active Operations

# %%
df_execution
# Out:
#          Job  Arrival Machine    Start  Simulated Processing Time  Flow time  \
# 0    Job_000     0.00      M0     0.00                      28.71      28.71
# 1    Job_000     0.00      M1    29.00                      84.52     113.52
# 2    Job_000     0.00      M2   113.52                       5.21     118.73
# 3    Job_000     0.00      M3   118.73                      27.01     145.74
# 4    Job_000     0.00      M4   152.00                      42.96     194.96
# ..       ...      ...     ...      ...                        ...        ...
# 152  Job_019   843.88      M0  1275.97                      67.95     500.04
# 153  Job_019   843.88      M1  1360.02                      39.67     555.81
# 154  Job_020   972.75      M0  1360.08                      38.38     425.71
# 155  Job_020   972.75      M1  1406.08                      76.14     509.47
# 156  Job_021  1013.15      M0  1398.46                      32.96     418.27
#
#          End
# 0      28.71
# 1     113.52
# 2     118.73
# 3     145.74
# 4     194.96
# ..       ...
# 152  1343.92
# 153  1399.69
# 154  1398.46
# 155  1482.22
# 156  1431.42
#
# [157 rows x 7 columns]

# %%
show.plot_gantt_machines(df_execution, "Gantt-Diagramm für simulierte Operationen vom ersten Tag", duration_column = "Simulated Processing Time")
show.plot_gantt_jobs(df_execution, "Gantt-Diagramm für simulierte Operationen vom ersten Tag", duration_column = "Simulated Processing Time")

# %%
# Operationen, die nicht am ersten Tag gestartet sind
convert.get_jssp_from_schedule(df_undone)
# Out:
# {'Job_017': [[8, 48]],
#  'Job_009': [[3, 52]],
#  'Job_015': [[5, 46]],
#  'Job_016': [[6, 7]]}

# %% [markdown]
# ### Verbliebene Jobs
# - "ursprünglicher Plan" - "simulierter Tag"

# %%
#df_rest = df_plan.merge(df_schedule_first_day[["Job", "Machine"]], on=["Job", "Machine"], how="left", indicator=True)
#df_rest = df_rest[df_rest["_merge"] == "left_only"].drop(columns=["_merge"])

df_rest = df_plan.merge(df_execution[["Job", "Machine"]], on=["Job", "Machine"], how="left", indicator=True)
df_rest = df_rest[df_rest["_merge"] == "left_only"].drop(columns=["_merge"])
df_rest
# Out:
#          Job  Arrival Machine    Start  Processing Time  Flow time      End
# 76   Job_007   329.63      M8  1476.20               19    1165.57  1495.20
# 77   Job_007   329.63      M9  1605.08               48    1323.45  1653.08
# 78   Job_007   329.63      M7  1653.08               36    1359.45  1689.08
# 79   Job_007   329.63      M3  1689.08               79    1438.45  1768.08
# 97   Job_009   429.20      M3  1407.14               52    1029.94  1459.14
# ..       ...      ...     ...      ...              ...        ...      ...
# 885  Job_088  5680.08      M9  9250.94               11    3581.86  9261.94
# 886  Job_088  5680.08      M6  9261.94               40    3621.86  9301.94
# 887  Job_088  5680.08      M7  9301.94               89    3710.86  9390.94
# 888  Job_088  5680.08      M4  9390.94               26    3736.86  9416.94
# 889  Job_088  5680.08      M8  9416.94               74    3810.86  9490.94
#
# [733 rows x 7 columns]

# %%
jssp_data_rest = convert.get_jssp_from_schedule(df_rest)
show.print_jobs(jssp_data_rest)
# Out:
# Job_007:  [[8, 19], [9, 48], [7, 36], [3, 79]]
# Job_009:  [[3, 52], [4, 90], [7, 45]]
# Job_010:  [[4, 26], [8, 74]]
# Job_013:  [[7, 12], [6, 89], [9, 45], [4, 33]]
# Job_014:  [[6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_015:  [[5, 46], [7, 72], [8, 30]]
# Job_016:  [[6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_017:  [[8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_018:  [[8, 21], [7, 49], [9, 72], [6, 53]]
# Job_019:  [[5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_020:  [[2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_021:  [[2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_022:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_023:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_024:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_025:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_026:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_027:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_028:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_029:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_030:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_031:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_032:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_033:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_034:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_035:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_036:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_037:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_038:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_039:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_040:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_041:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_042:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_043:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_044:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_045:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_046:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_047:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_048:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_049:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_050:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_051:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_052:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_053:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_054:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_055:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_056:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_057:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_058:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_059:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_060:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_061:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_062:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_063:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_064:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_065:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_066:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_067:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_068:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_069:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_070:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_071:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_072:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_073:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_074:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_075:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_076:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_077:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_078:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_079:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_080:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_081:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_082:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_083:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_084:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_085:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_086:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_087:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_088:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]

# %%
# Arrival Times der verbliebenen Jobs (wichtig keiene Duplikate)
df_arrival_rest = df_rest[["Job", "Arrival"]]
df_arrival_rest = df_arrival_rest.drop_duplicates(subset='Job', keep='first')
df_arrival_rest
# Out:
#          Job  Arrival
# 76   Job_007   329.63
# 97   Job_009   429.20
# 108  Job_010   473.82
# 136  Job_013   559.14
# 144  Job_014   561.12
# ..       ...      ...
# 840  Job_084  5519.69
# 850  Job_085  5542.52
# 860  Job_086  5591.92
# 870  Job_087  5644.29
# 880  Job_088  5680.08
#
# [79 rows x 2 columns]

# %% [markdown]
# ## Rescheduling für die nächsten Tage

# %%
def solve_jssp_weighted_with_fixed_operations_fast(job_dict, df_arrivals, df_executed,
                                                    solver_time_limit=300, epsilon=0.0,
                                                    arrival_column="Ankunftszeit (Minuten)",
                                                    reschedule_start=1440):
    """
    Schnelle Rescheduling-Variante mit fixierten Operationen.
    Plant alle verbleibenden Jobs ab reschedule_start, unter Berücksichtigung der letzten
    Endzeit bereits ausgeführter Operationen pro Job.
    """

    import pulp
    import pandas as pd

    print("🔁 Starte schnelles Rescheduling ab t =", reschedule_start)

    # Vorbereitung: Ankunftszeiten & Sortierung
    df_arrivals = df_arrivals.sort_values(arrival_column).reset_index(drop=True)
    arrival_times = df_arrivals.set_index("Job")[arrival_column].to_dict()
    job_names = list(df_arrivals.sort_values(arrival_column, ascending=False)["Job"])
    num_jobs = len(job_names)
    all_ops = [job_dict[job] for job in job_names]
    all_machines = {op[0] for job in all_ops for op in job}

    print(f"🔹 {num_jobs} Jobs erkannt")

    # Schnellzugriff vorbereiten
    job_index_map = {name: j for j, name in enumerate(job_names)}
    arrival_lookup = arrival_times

    # Letzte Endzeit bereits geplanter Operationen pro Job
    last_executed_end = df_executed.groupby("Job")["End"].max().to_dict()

    # Fixierte Maschinen-ID extrahieren
    df_executed = df_executed[df_executed["End"] >= reschedule_start].copy()
    df_executed["MachineID"] = df_executed["Machine"].str.extract(r"M(\d+)").astype(int)

    # Fixe Operationen gruppiert pro Maschine
    fixed_ops_dict = {
        m: list(zip(gr["Start"], gr["End"], gr["Job"]))
        for m, gr in df_executed.groupby("MachineID")
    }

    # LP-Modell
    prob = pulp.LpProblem("FastJSSP", pulp.LpMinimize)

    # Startzeit-Variablen
    starts = {
        (j, o): pulp.LpVariable(f"start_{j}_{o}", lowBound=0, cat="Continuous")
        for j in range(num_jobs)
        for o in range(len(all_ops[j]))
    }

    # Endzeit-Variablen je Job
    job_ends = {
        j: pulp.LpVariable(f"job_end_{j}", lowBound=0, cat="Continuous")
        for j in range(num_jobs)
    }

    # Gewichte
    weights = {j: 1 / (1 + arrival_lookup[job_names[j]]) for j in range(num_jobs)}

    # Zielfunktion
    prob += pulp.lpSum([
        weights[j] * (job_ends[j] - arrival_lookup[job_names[j]])
        for j in range(num_jobs)
    ])

    # Technologische Reihenfolge + individuelle Startbedingungen
    for j, job_name in enumerate(job_names):
        job = job_dict[job_name]
        earliest_start = max(
            arrival_lookup[job_name],
            last_executed_end.get(job_name, reschedule_start)
        )
        prob += starts[(j, 0)] >= earliest_start
        for o in range(1, len(job)):
            prob += starts[(j, o)] >= starts[(j, o - 1)] + job[o - 1][1]

    # Maschinenkonflikte (optimiert)
    bigM = 1e5
    for m in sorted(all_machines):
        ops = [(j, o, d) for j in range(num_jobs)
               for o, (mach, d) in enumerate(all_ops[j]) if mach == m]

        # Konflikte zwischen neuen Jobs (nur wenn j1 ≠ j2)
        for i in range(len(ops)):
            j1, o1, d1 = ops[i]
            for j2, o2, d2 in ops[i + 1:]:
                if j1 == j2:
                    continue  # gleicher Job → technologisch geregelt
                y = pulp.LpVariable(f"y_{j1}_{o1}_{j2}_{o2}", cat="Binary")
                prob += starts[(j1, o1)] + d1 + epsilon <= starts[(j2, o2)] + bigM * (1 - y)
                prob += starts[(j2, o2)] + d2 + epsilon <= starts[(j1, o1)] + bigM * y

        # Konflikte mit fixierten Operationen
        for j1, o1, d1 in ops:
            job1 = job_names[j1]
            job1_arrival = arrival_lookup.get(job1, 0)

            for fixed_start, fixed_end, fixed_job in fixed_ops_dict.get(m, []):
                if fixed_end + epsilon < job1_arrival:
                    continue
                y_fix = pulp.LpVariable(f"y_fix_{j1}_{o1}_{fixed_job}", cat="Binary")
                prob += starts[(j1, o1)] + d1 + epsilon <= fixed_start + bigM * (1 - y_fix)
                prob += fixed_end + epsilon <= starts[(j1, o1)] + bigM * y_fix

    # Endzeitbindung je Job
    for j in range(num_jobs):
        last_op = len(all_ops[j]) - 1
        prob += job_ends[j] >= starts[(j, last_op)] + all_ops[j][last_op][1]

    # Solver
    solver = pulp.HiGHS_CMD(msg=True, timeLimit=solver_time_limit)
    prob.solve(solver)

    # Ergebnis
    schedule_data = []
    for (j, o), var in sorted(starts.items()):
        start = var.varValue
        if start is not None:
            machine, duration = all_ops[j][o]
            end = start + duration
            schedule_data.append({
                "Job": job_names[j],
                "Machine": f"M{machine}",
                "Start": round(start, 2),
                "Processing Time": duration,
                "End": round(end, 2)
            })

    df_schedule = pd.DataFrame(schedule_data)
    df_schedule["Arrival"] = df_schedule["Job"].map(arrival_lookup)
    df_schedule["Flow time"] = df_schedule["End"] - df_schedule["Arrival"]
    df_schedule = df_schedule[["Job", "Arrival", "Machine", "Start", "Processing Time", "Flow time", "End"]]

    #total_weighted_flowtime = round(pulp.value(prob.objective), 3)
    #print("✅ Fertig! Zielwert:", total_weighted_flowtime)
    print("✅ Fertig!")
    return df_schedule

# %%
# Reduktion der bereits ausgeführten Operationen auf die relevanten für die nächsten Tage
df_execution_important = df_execution[df_execution["End"] >= 1440]
df_execution_important
# Out:
#          Job  Arrival Machine    Start  Simulated Processing Time  Flow time  \
# 39   Job_003   148.31      M5  1399.34                      60.21    1311.24
# 85   Job_008   344.30      M8  1402.55                      97.74    1155.99
# 100  Job_010   473.82      M7  1382.90                      74.77     983.85
# 110  Job_011   520.35      M4  1438.69                      41.94     960.28
# 137  Job_015   580.13      M6  1382.96                      58.68     861.51
# 144  Job_017   653.44      M3  1367.11                      87.62     801.29
# 155  Job_020   972.75      M1  1406.08                      76.14     509.47
#
#          End
# 39   1459.55
# 85   1500.29
# 100  1457.67
# 110  1480.63
# 137  1441.64
# 144  1454.73
# 155  1482.22

# %%
df_plan2 = solve_jssp_weighted_with_fixed_operations_fast(
    job_dict=jssp_data_rest,
    df_arrivals=df_arrival_rest,
    df_executed=df_execution_important,
    solver_time_limit=200,
    epsilon=0.6,
    arrival_column="Arrival",
    reschedule_start=1440
)
df_plan2
# Out:
# 🔁 Starte schnelles Rescheduling ab t = 1440
# 🔹 79 Jobs erkannt
# ✅ Fertig!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       1 df_plan2 = solve_jssp_weighted_with_fixed_operations_fast(
#       2     job_dict=jssp_data_rest,
#       3     df_arrivals=df_arrival_rest,
#    (...)
#       8     reschedule_start=1440
#       9 )
# ---> 11 df_schedule_new
#
# NameError: name 'df_schedule_new' is not defined

# %%
df = df_plan2
job_data = jssp_data_rest
text = "Gantt-Diagramm für die restlichen Tage"
show.plot_gantt_machines(df, text, duration_column = "Processing Time")
show.plot_gantt_jobs(df, text, duration_column = "Processing Time")

is_machine_conflict_free(df)
is_job_machine_sequence_correct(df, job_data)
is_start_correct(df)
# Out:
# True

# %% [markdown]
# ## Zusammenführung der Simulation mit dem restlichen Plan

# %%
df_execution = df_execution.rename(columns={"Simulated Processing Time": "Processing Time"})

df_schedule_mix = pd.concat([df_execution, df_plan2], ignore_index=True)
df_schedule_mix = df_schedule_mix.sort_values(by="Start").reset_index(drop=True)
df_schedule_mix
# Out:
#          Job  Arrival Machine     Start  Processing Time  Flow time       End
# 0    Job_000     0.00      M0      0.00            28.71      28.71     28.71
# 1    Job_000     0.00      M1     29.00            84.52     113.52    113.52
# 2    Job_001    84.93      M0     84.93            40.58      40.58    125.51
# 3    Job_000     0.00      M2    113.52             5.21     118.73    118.73
# 4    Job_002   106.18      M1    113.52            65.42      72.76    178.94
# ..       ...      ...     ...       ...              ...        ...       ...
# 885  Job_088  5680.08      M9  24242.09            11.00   18573.01  24253.09
# 886  Job_088  5680.08      M6  24253.09            40.00   18613.01  24293.09
# 887  Job_088  5680.08      M7  24293.09            89.00   18702.01  24382.09
# 888  Job_088  5680.08      M4  24382.09            26.00   18728.01  24408.09
# 889  Job_088  5680.08      M8  24408.09            74.00   18802.01  24482.09
#
# [890 rows x 7 columns]

# %%
df = df_schedule_mix
job_data = jssp_data
text = "Gantt-Diagramm für alle Tage (mix)"
show.plot_gantt_machines(df, text, duration_column = "Processing Time")
show.plot_gantt_jobs(df, text, duration_column = "Processing Time")

is_machine_conflict_free(df)
is_job_machine_sequence_correct(df, job_data)
is_start_correct(df)
# Out:
# True

# %%
def is_job_timing_correct(df_schedule: pd.DataFrame) -> bool:
    """
    Prüft nur die zeitliche technologische Reihenfolge pro Job:
    Jede Operation muss frühestens nach Ende der vorherigen starten.
    Gibt True zurück, wenn alles korrekt ist.
    Gibt False zurück und zeigt fehlerhafte Zeitabfolgen.
    """
    df = df_schedule.copy()
    df = df.sort_values(["Job", "Start"]).reset_index(drop=True)

    violations = []

    for job in df["Job"].unique():
        df_job = df[df["Job"] == job].sort_values("Start").reset_index(drop=True)

        for i in range(1, len(df_job)):
            prev_end = df_job.loc[i - 1, "End"]
            curr_start = df_job.loc[i, "Start"]
            if curr_start < prev_end:
                violations.append((job, i, round(prev_end, 2), round(curr_start, 2)))

    if not violations:
        print("✅ Zeitliche technologische Reihenfolge korrekt.")
        return True
    else:
        print(f"❌ {len(violations)} Zeitverletzungen gefunden:")
        for job, i, prev_end, curr_start in violations:
            print(f"  ⏱️  Job {job} – Operation {i} startet zu früh: {curr_start} < {prev_end}")
        return False
        
is_job_timing_correct(df)
# Out:
# ✅ Zeitliche technologische Reihenfolge korrekt.
# True

# %%
df_execution.to_csv("data/04a_schedule_simulation.csv", index = False)
df_plan2.to_csv("data/04b_schedule_plan2.csv", index = False)
df_schedule_mix.to_csv("data/04c_schedule_mix.csv", index = False)
