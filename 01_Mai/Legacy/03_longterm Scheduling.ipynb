# %% [markdown]
# # Langzeit Scheduling

# %% [markdown]
# <b> Erkenntnisse: </b>
# - Job-Reihenfolge im Solver ist relevant

# %%
import json
import pandas as pd
import numpy as np
import random

# %%
import pulp

# %%
import utils.schedule_interarrival as sit

# %%
import utils.presenter as show
import utils.schedule_solver as ssv

# %%
from utils.checker import is_machine_conflict_free
from utils.checker import is_job_machine_sequence_correct
from utils.checker import is_start_correct

# %%
pd.set_option('display.max_rows', 30)

# %%
# Datei laden
with open("data/jobshop_instances.json", "r", encoding="utf-8") as f:
    jobshop_instances = json.load(f)

instance =  jobshop_instances["instance ft10"]
show.print_jobs(instance)
# Out:
# job 0:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# job 1:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# job 2:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# job 3:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# job 4:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# job 5:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# job 6:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# job 7:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# job 8:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# job 9:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]

# %%
def add_jobs_to_dict(job_set_dict, new_instance, shuffle=False, seed=50):
    offset = len(job_set_dict)
    items = list(new_instance.items())

    if shuffle:
        random.seed(seed)
        random.shuffle(items)

    for i, (_, ops) in enumerate(items):
        job_name = f"Job_{offset + i:03d}"
        job_set_dict[job_name] = ops

# %%
def generate_jobs_for_days(day_numb: int, jobs_instance: dict):
    jssp_data = {}

    # Schritt 1: Ursprüngliche Instanz vervielfachen (geschätzt mit Puffer)
    for i in range(int(2.3 *day_numb)):
        shuffle = False if (i % 2 == 0) else True
        add_jobs_to_dict(jssp_data, jobs_instance, shuffle)

    # Schritt 2: Zwischenankunftszeiten berechnen
    mean_interarrival_time = sit.calculate_mean_interarrival_time(jssp_data)
    df_arrivals = sit.generate_job_arrivals_df_by_mean_interarrival_time(jssp_data, t_a=mean_interarrival_time)

    
    # Schritt 3a: Filter auf df_arrivals anwenden
    df_arrivals = df_arrivals[df_arrivals["Ankunftszeit (Minuten)"] <= (60 * 24 * day_numb)]
    df_arrivals

    # Schritt 3b: Nur die verbleibenden Job-IDs extrahieren
    valid_job_ids = set(df_arrivals["Job-ID"])

    # Schritt 3c: jssp_data kürzen
    jssp_data = {job_id: ops for job_id, ops in jssp_data.items() if job_id in valid_job_ids}

    return jssp_data, df_arrivals

# %%
jssp_data, df_arrivals = generate_jobs_for_days(4, instance)
show.print_jobs(jssp_data)
# Out:
# Job_000:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_001:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_002:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_003:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_004:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_005:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_006:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_007:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_008:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_009:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_010:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_011:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_012:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_013:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_014:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_015:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_016:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_017:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_018:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_019:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_020:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_021:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_022:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_023:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_024:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_025:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_026:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_027:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_028:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_029:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_030:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_031:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_032:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_033:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_034:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_035:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_036:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_037:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_038:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_039:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_040:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_041:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_042:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_043:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_044:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_045:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_046:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_047:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_048:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_049:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_050:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_051:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_052:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_053:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_054:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_055:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_056:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_057:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_058:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_059:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_060:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_061:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_062:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_063:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_064:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_065:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_066:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_067:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_068:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_069:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_070:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]
# Job_071:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_072:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_073:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_074:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_075:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_076:  [[1, 85], [0, 13], [2, 61], [6, 7], [8, 64], [9, 76], [5, 47], [3, 52], [4, 90], [7, 45]]
# Job_077:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_078:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_079:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_080:  [[0, 29], [1, 78], [2, 9], [3, 36], [4, 49], [5, 11], [6, 62], [7, 56], [8, 44], [9, 21]]
# Job_081:  [[0, 43], [2, 90], [4, 75], [9, 11], [3, 69], [1, 28], [6, 46], [5, 46], [7, 72], [8, 30]]
# Job_082:  [[1, 91], [0, 85], [3, 39], [2, 74], [8, 90], [5, 10], [7, 12], [6, 89], [9, 45], [4, 33]]
# Job_083:  [[1, 81], [2, 95], [0, 71], [4, 99], [6, 9], [8, 52], [7, 85], [3, 98], [9, 22], [5, 43]]
# Job_084:  [[2, 14], [0, 6], [1, 22], [5, 61], [3, 26], [4, 69], [8, 21], [7, 49], [9, 72], [6, 53]]
# Job_085:  [[2, 84], [1, 2], [5, 52], [3, 95], [8, 48], [9, 72], [0, 47], [6, 65], [4, 6], [7, 25]]
# Job_086:  [[1, 46], [0, 37], [3, 61], [2, 13], [6, 32], [5, 21], [9, 32], [8, 89], [7, 30], [4, 55]]
# Job_087:  [[2, 31], [0, 86], [1, 46], [5, 74], [4, 32], [6, 88], [8, 19], [9, 48], [7, 36], [3, 79]]
# Job_088:  [[0, 76], [1, 69], [3, 76], [5, 51], [2, 85], [9, 11], [6, 40], [7, 89], [4, 26], [8, 74]]

# %%
df_arrivals
# Out:
#      Job-ID  Ankunftszeit (Minuten)
# 0   Job_000                    0.00
# 1   Job_001                   84.93
# 2   Job_002                  106.18
# 3   Job_003                  148.31
# 4   Job_004                  185.08
# ..      ...                     ...
# 84  Job_084                 5519.69
# 85  Job_085                 5542.52
# 86  Job_086                 5591.92
# 87  Job_087                 5644.29
# 88  Job_088                 5680.08
#
# [89 rows x 2 columns]

# %% [markdown]
# ## 1) Two Stages
# 1. Globales Makespan minimieren
# 2. Jobs (alle Operationen) möglichst an die Ankunftszeit bringen

# %%
df_plan_stage1, makespan = ssv.solve_jssp_global_makespan(jssp_data, df_arrivals, solver_time_limit=1800, epsilon=0.06)
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 1800
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/95438ab5039e4ccb859f7bd8ce847a9f-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/95438ab5039e4ccb859f7bd8ce847a9f-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  95438ab5039e4ccb859f7bd8ce847a9f-pulp has 79299 rows; 40051 cols; 236829 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79210 rows, 40051 cols, 236740 nonzeros  0s
# 40050 rows, 40051 cols, 119260 nonzeros  0s
# 40050 rows, 40051 cols, 119260 nonzeros  0s
#
# Solving MIP model with:
#    40050 rows
#    40051 cols (39160 binary, 0 integer, 0 implied int., 891 continuous)
#    119260 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   6277.08         inf                  inf        0      0      0         0     0.1s
#  R       0       0         0   0.00%   6277.08         27373.28          77.07%        0      0      0      1903     0.3s
#          0       0         0   0.00%   6292.140131     27373.28          77.01%     8931    589      0     17162     5.4s
#  L       0       0         0   0.00%   6292.140131     14022.53          55.13%     9384    487      0     18513    47.7s
#  L       0       0         0   0.00%   6292.140131     11624.18          45.87%     9384    236      0     23923    88.2s
#        302     299         2   0.00%   6292.140131     11624.18          45.87%     9386    236      2     41482    95.9s
#        571     564         4   0.00%   6292.140131     11624.18          45.87%     9924    368      4     48676   102.1s
#       1315    1298         8   0.00%   6292.140131     11624.18          45.87%     8709    404     17     62698   116.1s
#  L    1315    1297         8   0.00%   6292.140131     11381.77          44.72%     9090    469     30     63213   164.7s
#       1606    1587         9   0.00%   6292.140131     11381.77          44.72%     9091    469     31     84302   171.1s
#  L    1606    1586         9   0.00%   6292.140131     10842.93          41.97%     9360    523     43     85006   246.8s
#  L    1747    1717        14   0.00%   6292.140131     10628.75          40.80%     9676    577     62    106526   302.7s
#       2098    2055        21   0.00%   6292.140131     10628.75          40.80%     9682    577     74    127196   309.2s
#  L    2098    2054        21   0.00%   6292.140131     10600.09          40.64%     9657    643     85    128355   391.4s
#       2866    2818        23   0.00%   6292.140131     10600.09          40.64%     9659    643     90    156356   406.1s
#  L    2866    2817        23   0.00%   6292.140131     10365.23          39.30%     9795    513    102    156964   460.9s
#       3195    3143        24   0.00%   6292.140131     10365.23          39.30%     9796    513    107    181076   467.6s
#  L    3195    3142        24   0.00%   6292.140131     9828.39           35.98%     9908    589    126    182006   524.2s
#       4314    4255        27   0.00%   6292.140131     9828.39           35.98%     9911    589    133    216880   544.1s
#  L    4314    4254        27   0.00%   6292.140131     9004.99           30.13%     9980    665    145    217795   590.7s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#       4679    4615        29   0.00%   6292.140131     9004.99           30.13%     9982    665    152    246555   598.0s
#  L    4679    4614        29   0.00%   6292.140131     8826.39           28.71%    11046   1026    152    248005   651.1s
#       5379    5313        30   0.00%   6292.140131     8826.39           28.71%    11047   1026    153    416586   709.1s
#       5392    5312        31   0.00%   6292.140131     8826.39           28.71%    11274   1101    157    448510  1094.4s
#       5998    5926        33   0.00%   6292.140131     8826.39           28.71%    11276   1101    161    459101  1108.1s
#       5999    5926        34   0.00%   6292.140131     8826.39           28.71%    11349    542    165    494337  1800.1s
#       5999    5926        34   0.00%   6292.140131     8826.39           28.71%    11349    542    165    494337  1800.1s
#
# Solving report
#   Model             95438ab5039e4ccb859f7bd8ce847a9f-pulp
#   Status            Time limit reached
#   Primal bound      8826.38999994
#   Dual bound        6292.14013068
#   Gap               28.71% (tolerance: 0.01%)
#   P-D integral      615.407930668
#   Solution status   feasible
#                     8826.38999994 (objective)
#                     0 (bound viol.)
#                     7.59308410012e-10 (int. viol.)
#                     0 (row viol.)
#   Timing            1800.08 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 16
#   Nodes             5999
#   Repair LPs        1 (1 feasible; 1166 iterations)
#   LP iterations     494337 (total)
#                     0 (strong br.)
#                     29331 (separation)
#                     199117 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/95438ab5039e4ccb859f7bd8ce847a9f-pulp.sol

# %%
df = df_plan_stage1
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

is_machine_conflict_free(df)
is_job_machine_sequence_correct(df, jssp_data)
is_start_correct(df)
# Out:
# True

# %%
# df_plan_stage2, optimal_makespan = ssv.solve_stage2_early_starts_all(jssp_data, df_arrivals, makespan, solver_time_limit=1800, epsilon=0.06)
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 100
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/05e59c5fc3f54e52b0141a92b1b4d404-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/05e59c5fc3f54e52b0141a92b1b4d404-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  05e59c5fc3f54e52b0141a92b1b4d404-pulp has 79299 rows; 40050 cols; 236740 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79121 rows, 40050 cols, 236562 nonzeros  0s
# 46855 rows, 40050 cols, 139764 nonzeros  0s
# 46855 rows, 40050 cols, 139764 nonzeros  0s
#
# Solving MIP model with:
#    46855 rows
#    40050 cols (39160 binary, 0 integer, 0 implied int., 890 continuous)
#    139764 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   2323107.13      inf                  inf        0      0      0         0     0.1s
#          0       0         0   0.00%   2734169.7       inf                  inf        0      0      0      2268     0.3s
#          0       0         0   0.00%   2764496.061735  inf                  inf    11253   2420     58      7289     5.4s
#          0       0         0   0.00%   2769633.670403  inf                  inf    14949   3636     61     12674    10.4s
#          0       0         0   0.00%   2771651.767697  inf                  inf    14263   3289     61     18057    15.7s
#          0       0         0   0.00%   2772375.324444  inf                  inf    12028   2464     62     22279    20.9s
#          0       0         0   0.00%   2772984.43195   inf                  inf    13540   3106     66     27865    26.2s
#          0       0         0   0.00%   2773021.030377  inf                  inf    11264   3199     66     30944   100.1s
#
# Solving report
#   Model             05e59c5fc3f54e52b0141a92b1b4d404-pulp
#   Status            Time limit reached
#   Primal bound      inf
#   Dual bound        2773021.03038
#   Gap               inf
#   P-D integral      0
#   Solution status   -
#   Timing            100.06 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 5
#   Nodes             0
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     30944 (total)
#                     0 (strong br.)
#                     26050 (separation)
#                     2626 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/05e59c5fc3f54e52b0141a92b1b4d404-pulp.sol
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_plan_stage2, optimal_makespan = ssv.solve_stage2_early_starts_all(jssp_data, df_arrivals, makespan, solver_time_limit=100, epsilon=0.06)
#
# File ~/Coding/HTWD_JSSP/01_Mai/utils/schedule_solver.py:407, in solve_stage2_early_starts_all(job_dict, df_arrivals, optimal_makespan, solver_time_limit, epsilon)
#     397         schedule_data.append({
#     398             "Job": job_names[j],
#     399             "Machine": f"M{machine}",
#    (...)
#     402             "End": round(end, 2)
#     403         })
#     405 df_schedule = pd.DataFrame(schedule_data)
# --> 407 df_schedule["Arrival"] = df_schedule["Job"].map(arrival_times)
#     408 df_schedule["Flow time"] = df_schedule["End"] - df_schedule["Arrival"]
#     410 # Spaltenreihenfolge anpassen
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Job'

# %%
df = df_plan_stage2 if df_plan_stage2 else df_plan_stage1
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

is_machine_conflict_free(df)
is_job_machine_sequence_correct(df, jssp_data)
is_start_correct(df, df_arrivals)

# %%
print(f"Globale Makespan:{max(df.End)}")

# %%
df_job_flow = (
    df.groupby("Job")
    .agg({"Arrival": "first", "Start": "min","End": "max"})
    .rename(columns={"Arrival": "Arrival Time", "Start": "Start", "End": "Completion Time"})
    .reset_index()
)
df_job_flow

# %%
df.to_csv("data/03_schedule_by_stages.csv", index = False)

# %% [markdown]
# ## 2) Indivuelle Flowtimes (Makespans) minimieren
# Flowtime eines Jobs = "Ende der letzen Operation des Jobs" - "Ankunftszeit des Jobs"
#
# - Jobs werden nach Ankunftszeit sotiert (absteigend) da es bessere Resultate liefert

# %% [markdown]
# ### A) Ungewichtet

# %%
df_plan_2a, total = ssv.solve_jssp_individual_flowtime(jssp_data, df_arrivals, solver_time_limit=1800, epsilon=0.06)
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 1800
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/f8c500d2589945829feee9238149797d-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/f8c500d2589945829feee9238149797d-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  f8c500d2589945829feee9238149797d-pulp has 79299 rows; 40139 cols; 236829 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79121 rows, 40050 cols, 236562 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
#
# Solving MIP model with:
#    39961 rows
#    40050 cols (39160 binary, 0 integer, 0 implied int., 890 continuous)
#    119082 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   297703.47       inf                  inf        0      0      0         0     0.1s
#  R       0       0         0   0.00%   297732.47       1236652.96        75.92%        0      0      0      2025     0.3s
#          0       0         0   0.00%   301727.115036   1236652.96        75.60%    12021   3287      0     18145     5.4s
#          0       0         0   0.00%   301955.595642   1236652.96        75.58%    11605   2865      0     29603    10.6s
#          0       0         0   0.00%   302066.987441   1236652.96        75.57%    12072   2918      0     39674    15.9s
#  L       0       0         0   0.00%   302080.475649   511100.16         40.90%    12059   2672      0     43566    73.3s
#        131     128         2   0.00%   302080.475649   511100.16         40.90%    10314   1127      2     70958    79.2s
#        260     255         3   0.00%   302150.309898   511100.16         40.88%    11353   1765      3    101536    97.5s
#  L     260     254         3   0.00%   302150.309898   509643.62         40.71%    11694   1606      3    105823   165.3s
#        406     399         4   0.00%   302150.309898   509643.62         40.71%    11695   1606      4    136885   171.3s
#        583     574         5   0.00%   302150.309898   509643.62         40.71%    11642   2551      5    157062   182.2s
#        800     789         6   0.00%   302150.309898   509643.62         40.71%    13763   2887      6    179354   191.4s
#        895     788         7   0.00%   302150.309898   509643.62         40.71%    11642   1545      7    192409   197.1s
#       1032    1013        10   0.00%   302150.309898   509643.62         40.71%    10982   1847     10    208937   204.3s
#  L    1032    1012        10   0.00%   302150.309898   480797.08         37.16%    10267   2324     10    212071   257.1s
#  L    1139    1117        11   0.00%   302150.309898   477720.84         36.75%    11284   1568     11    247192   406.7s
#  L    1256    1232        12   0.00%   302150.309898   476723.78         36.62%    10120   1859     12    293300   484.2s
#       1388    1361        14   0.00%   302150.309898   476723.78         36.62%    10122   1859     14    333955   491.0s
#  L    1388    1360        14   0.00%   302150.309898   476598.6          36.60%    11179   2014     14    335125   569.6s
#       1484    1361        18   0.00%   302150.309898   476598.6          36.60%    11183   2014     18    384333   574.7s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L    1529    1491        19   0.00%   302150.309898   474466.3          36.32%    13336   2343     19    392028   655.7s
#       1747    1702        23   0.00%   302150.309898   474466.3          36.32%    13339   2343     22    437481   663.9s
#  L    1747    1701        23   0.00%   302150.309898   465620.62         35.11%     7898   1928     22    440212   714.6s
#       1844    1702        26   0.00%   302150.309898   465620.62         35.11%     7901   1928     25    472871   719.9s
#  L    1877    1823        27   0.00%   302150.309898   464242.48         34.92%    10339   1683     26    476742   801.3s
#       1976    1824        30   0.00%   302150.309898   464242.48         34.92%    10341   1683     29    533295   807.8s
#  L    1982    1920        31   0.00%   302150.309898   450533.599999     32.94%    11239   2207     30    537834  1005.3s
#       2068    1920        32   0.00%   302150.309898   450533.599999     32.94%    11240   2207     31    583236  1011.4s
#  L    2097    2031        33   0.00%   302150.309898   450406.42         32.92%    12920   2021     33    586882  1115.1s
#       2215    2123        44   0.00%   302150.309898   450406.42         32.92%     8164   2074     44    639084  1120.6s
#       2398    2212        53   0.00%   302150.309898   450406.42         32.92%    13989   2680     55    654138  1127.2s
#       2430    2310        55   0.00%   302150.309898   450406.42         32.92%     8914   1140     60    689937  1602.8s
#       2645    2518        64   0.00%   302150.309898   450406.42         32.92%    10373   1322     69    701264  1609.1s
#       2798    2649        69   0.00%   302150.309898   450406.42         32.92%    11336   2068     74    718508  1615.5s
#       3376    3229        74   0.00%   302150.309898   450406.42         32.92%    11340   2068     79    725662  1628.3s
#       3492    3327        81   0.00%   302150.309898   450406.42         32.92%    12367   1830     88    740026  1633.8s
#       4283    4102        91   0.00%   302150.309898   450406.42         32.92%    12377   1830     98    757623  1650.4s
#       4284    4102        92   0.00%   302150.309898   450406.42         32.92%     8138   1905     98    777403  1800.7s
#       4284    4102        92   0.00%   302150.309898   450406.42         32.92%     8138   1905     98    777403  1800.7s
#
# Solving report
#   Model             f8c500d2589945829feee9238149797d-pulp
#   Status            Time limit reached
#   Primal bound      450406.42
#   Dual bound        302150.309898
#   Gap               32.92% (tolerance: 0.01%)
#   P-D integral      661.932555235
#   Solution status   feasible
#                     450406.42 (objective)
#                     0 (bound viol.)
#                     1.81898940355e-17 (int. viol.)
#                     0 (row viol.)
#   Timing            1800.70 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 13
#   Nodes             4284
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     777403 (total)
#                     0 (strong br.)
#                     107479 (separation)
#                     334873 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/f8c500d2589945829feee9238149797d-pulp.sol

# %%
df = df_plan_2a
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

is_machine_conflict_free(df)
is_job_machine_sequence_correct(df, jssp_data)
is_start_correct(df)
# Out:
# True

# %%
print(f"Globale Makespan:{max(df.End)}")
# Out:
# Globale Makespan:9519.87

# %%
df_job_flow = (
    df.groupby("Job")
    .agg({"Arrival": "first", "Start": "min","End": "max"})
    .rename(columns={"Arrival": "Arrival Time", "Start": "Start", "End": "Completion Time"})
    .reset_index()
)
df_job_flow
# Out:
#         Job  Arrival Time    Start  Completion Time
# 0   Job_000          0.00     0.00           395.00
# 1   Job_001         84.93    84.93           655.61
# 2   Job_002        106.18   107.06           936.01
# 3   Job_003        148.31   198.12          1179.19
# 4   Job_004        185.08   217.99           911.07
# ..      ...           ...      ...              ...
# 84  Job_084       5519.69  8180.51          9238.63
# 85  Job_085       5542.52  8194.57          9294.75
# 86  Job_086       5591.92  8253.57          8996.51
# 87  Job_087       5644.29  8278.63          9409.81
# 88  Job_088       5680.08  8680.51          9519.87
#
# [89 rows x 4 columns]

# %%
df.to_csv("data/03a_schedule_by_individual_flowtime.csv", index = False)

# %% [markdown]
# ### B) Gewichtet (wenn früher arrival)

# %%
df_plan_2b, total = ssv.solve_jssp_weighted_individual_flowtime(jssp_data, df_arrivals, solver_time_limit=1800, epsilon=0.06)
# Out:
# Running HiGHS 1.10.0 (git hash: n/a): Copyright (c) 2025 HiGHS under MIT licence terms
# Set option time_limit to 1800
# Set option solution_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/18301c855f3c418da8a2f0b12ad70cee-pulp.sol"
# Set option log_file to "/var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/18301c855f3c418da8a2f0b12ad70cee-pulp.HiGHS_log"
# Set option write_solution_to_file to true
# Number of BV entries in BOUNDS section is 39160
# MIP  18301c855f3c418da8a2f0b12ad70cee-pulp has 79299 rows; 40139 cols; 236829 nonzeros; 39160 integer variables (39160 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+05]
#   Cost   [2e-04, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e+00, 1e+05]
# Presolving model
# 79121 rows, 40050 cols, 236562 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
# 39961 rows, 40050 cols, 119082 nonzeros  0s
#
# Solving MIP model with:
#    39961 rows
#    40050 cols (39160 binary, 0 integer, 0 implied int., 890 continuous)
#    119082 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point; X => User solution
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   501.2321563     inf                  inf        0      0      0         0     0.1s
#  R       0       0         0   0.00%   530.2321563     903.2769223       41.30%        0      0      0      2211     0.3s
#          0       0         0   0.00%   533.6460546     903.2769223       40.92%    11117   2984      0     20333     5.5s
#          0       0         0   0.00%   534.1031229     903.2769223       40.87%    12236   3832      0     33200    11.1s
#          0       0         0   0.00%   534.3796639     903.2769223       40.84%    13344   3226      0     47203    16.7s
#          0       0         0   0.00%   534.555755      903.2769223       40.82%    14155   3604      0     63688    23.4s
#          0       0         0   0.00%   534.6023555     903.2769223       40.82%    11689   2620      0     80887    29.6s
#          0       0         0   0.00%   534.6527501     903.2769223       40.81%    10209   2358      0     93902    34.9s
#          0       0         0   0.00%   534.7014527     903.2769223       40.80%    12513   2860      0    112431    41.7s
#          0       0         0   0.00%   534.7432465     903.2769223       40.80%    10694   2790      0    134440    48.5s
#          0       0         0   0.00%   534.7679113     903.2769223       40.80%    12443   2595      0    149040    55.1s
#          0       0         0   0.00%   534.7795143     903.2769223       40.80%    11608   2894      0    162997    61.2s
#          0       0         0   0.00%   534.797619      903.2769223       40.79%    10617   2328      0    178815    68.2s
#          0       0         0   0.00%   534.8079822     903.2769223       40.79%    11969   2566      0    193540    74.6s
#          0       0         0   0.00%   534.823799      903.2769223       40.79%    12380   2065      0    207354    93.5s
#          0       0         0   0.00%   534.8296781     903.2769223       40.79%    12267   2781      0    224117   101.0s
#          0       0         0   0.00%   534.8327034     903.2769223       40.79%    12933   3177      0    277141   121.6s
#  L       0       0         0   0.00%   534.8327034     608.9192758       12.17%    12933   3177      0    277141   184.2s
#  L       0       0         0   0.00%   534.8327034     608.0209501       12.04%     8458    618      0    296508   265.0s
#        144     143         1   0.00%   534.8327034     608.0209501       12.04%     8459    618      1    348687   275.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#        220     142         2   0.00%   534.8327034     608.0209501       12.04%     7799   1656      2    400552   296.7s
#        396     305         4   0.00%   534.8464893     608.0209501       12.03%    12535   2536      4    462323   324.4s
#        502     493         5   0.00%   534.8464893     608.0209501       12.03%    12536   2536      5    472244   329.6s
#        521     493         6   0.00%   534.8464893     608.0209501       12.03%    13034   2993      6    512819   344.6s
#        603     590         7   0.00%   534.8464893     608.0209501       12.03%    13034   2993      7    529557   352.2s
#        697     589         8   0.00%   534.8464893     608.0209501       12.03%    12977   2232      8    600325   378.8s
#  L     744     726         9   0.00%   534.8464893     606.7598835       11.85%    11287   2410      9    611842   530.6s
#        819     727        10   0.00%   534.8464893     606.7598835       11.85%    11288   2410     10    709958   541.5s
#  L     878     853        12   0.00%   534.8464893     606.3156653       11.79%    14421   2800     14    723163   667.2s
#        926     853        13   0.00%   534.8464893     606.3156653       11.79%    14422   2800     15    793918   675.3s
#       1043    1015        14   0.00%   534.8464893     606.3156653       11.79%    14423   2800     16    807010   682.7s
#  L    1043    1014        14   0.00%   534.8464893     606.0222127       11.74%    12387   3062     16    812008   758.8s
#       1115    1014        15   0.00%   534.8464893     606.0222127       11.74%    12388   3062     17    890331   771.0s
#  L    1147    1114        16   0.00%   534.8464893     604.4812016       11.52%    13857   1645     18    899990   858.8s
#       1217    1114        17   0.00%   534.8464893     604.4812016       11.52%    13858   1645     19    995588   869.5s
#  L    1296    1243        18   0.00%   534.8464893     604.4633481       11.52%     6727   1871     37     1003k   958.8s
#       1332    1243        19   0.00%   534.8464893     604.4633481       11.52%     6728   1871     38     1066k   964.8s
#       1400    1344        20   0.00%   534.8464893     604.4633481       11.52%     6728   1871     38     1080k   970.0s
#  L    1400    1342        20   0.00%   534.8464893     604.1283462       11.47%     8180   2053     38     1084k  1046.5s
#       1436    1342        22   0.00%   534.8464893     604.1283462       11.47%     8182   2053     40     1171k  1055.8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L    1507    1435        27   0.00%   534.8464893     603.6694942       11.40%    11080   2503     42     1188k  1139.3s
#       1580    1437        28   0.00%   534.8464893     603.6694942       11.40%    11080   2503     43     1266k  1150.1s
#  L    1607    1513        38   0.00%   534.8464893     603.5503565       11.38%    12709   2677     53     1273k  1220.7s
#       1667    1514        42   0.00%   534.8464893     603.5503565       11.38%    12712   2677     56     1351k  1230.6s
#       1753    1642        47   0.00%   534.8464893     603.5503565       11.38%    12712   2677     57     1365k  1235.7s
#  L    1753    1641        47   0.00%   534.8464893     603.4460389       11.37%     8381   1354     57     1368k  1308.9s
#       1810    1642        50   0.00%   534.8464893     603.4460389       11.37%     8384   1354     60     1425k  1316.0s
#  L    2047    1899        51   0.00%   534.8464893     603.4057692       11.36%    11090   1730     89     1439k  1408.7s
#       2103    1902        56   0.00%   534.8464893     603.4057692       11.36%    11094   1730     94     1519k  1416.3s
#       2436    2275        58   0.00%   534.8464893     603.4057692       11.36%    11094   1730     94     1543k  1430.6s
#  L    2436    2274        58   0.00%   534.8464893     602.6315226       11.25%    12252   1907     94     1546k  1519.0s
#       2480    2275        60   0.00%   534.8464893     602.6315226       11.25%    12254   1907     96     1619k  1526.4s
#       3111    2941        62   0.00%   534.8464893     602.6315226       11.25%    12254   1907     97     1672k  1554.0s
#  L    3111    2932        62   0.00%   534.8464893     599.0223256       10.71%     9105   2088     97     1676k  1681.4s
#       3458    3276        64   0.00%   534.8464893     599.0223256       10.71%     9106   2088     98     1791k  1705.9s
#  L    3458    3268        64   0.00%   534.8464893     598.707754        10.67%    10301   1294     98     1796k  1783.6s
#       3554    3269        70   0.00%   534.8464893     598.707754        10.67%    10305   1294    103     1865k  1791.6s
#       3570    3366        72   0.00%   534.8464893     598.707754        10.67%    11428   1450    103     1888k  1800.3s
#       3570    3366        72   0.00%   534.8464893     598.707754        10.67%    11428   1450    103     1888k  1800.3s
#
# Solving report
#   Model             18301c855f3c418da8a2f0b12ad70cee-pulp
#   Status            Time limit reached
#   Primal bound      598.707754025
#   Dual bound        534.846489331
#   Gap               10.67% (tolerance: 0.01%)
#   P-D integral      262.023229478
#   Solution status   feasible
#                     598.707754025 (objective)
#                     0 (bound viol.)
#                     9.54791801178e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            1800.33 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 11
#   Nodes             3570
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1888881 (total)
#                     0 (strong br.)
#                     426717 (separation)
#                     669634 (heuristics)
# Writing the solution to /var/folders/88/5n59t5yx3095jhz9lldbm0kr0000gn/T/18301c855f3c418da8a2f0b12ad70cee-pulp.sol

# %%
df = df_plan_2b
category = "3 Tage"
show.plot_gantt_jobs(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")
show.plot_gantt_machines(df, 'Gantt-Diagramm für "{}"'.format(category), duration_column = "Processing Time")

is_machine_conflict_free(df)
is_job_machine_sequence_correct(df, jssp_data)
is_start_correct(df)
# Out:
# True

# %%
print(f"Globale Makespan:{max(df.End)}")
# Out:
# Globale Makespan:9490.94

# %%
df_job_flow = (
    df.groupby("Job")
    .agg({"Arrival": "first", "Start": "min","End": "max"})
    .rename(columns={"Arrival": "Arrival Time", "Start": "Start", "End": "Completion Time"})
    .reset_index()
)
df_job_flow
# Out:
#         Job  Arrival Time    Start  Completion Time
# 0   Job_000          0.00     0.00           395.00
# 1   Job_001         84.93    84.93           635.24
# 2   Job_002        106.18   107.06           787.30
# 3   Job_003        148.31   198.12          1377.02
# 4   Job_004        185.08   217.99           879.36
# ..      ...           ...      ...              ...
# 84  Job_084       5519.69  7810.16          8816.76
# 85  Job_085       5542.52  7824.22          9204.88
# 86  Job_086       5591.92  8201.52          9117.88
# 87  Job_087       5644.29  8129.46          9365.88
# 88  Job_088       5680.08  8417.70          9490.94
#
# [89 rows x 4 columns]

# %%
df.to_csv("data/03b_schedule_by_individual_flowtime_weighted.csv", index = False)
