# %% [markdown]
# # Rolling Planning mit Summe-Tardiness

# %%
import json
import pandas as pd
pd.set_option('display.max_rows', 40)

import utils.rolling_planning.rescheduling as reschedul

# %% [markdown]
# ## Laden der Initialisierungsdaten

# %%
df_jssp = pd.read_csv("data/07_tardiness_init_jssp.csv")
df_times = pd.read_csv("data/07_tardiness_init_times.csv")

# %% [markdown]
# ### Tag 0

# %%
df_plan = pd.read_csv("data/07_tardiness_init_plan.csv")
df_execution = pd.read_csv("data/07_tardiness_init_execution.csv")
df_undone = pd.read_csv("data/07_tardiness_init_undone.csv")

# %% [markdown]
# ## Settings

# %%
solver_limit = 60*60*4 # 4 h
solver_limit

notebook_prefix = "07b_without"

# %% [markdown]
# ## Params

# %%
# fix
day_length = 1440
horizon_days = 3

# %% [markdown]
# ## Rescheduling für Tage 1-4

# %%
reschedul.run_multi_day_rescheduling(first_start=1, last_planning_start=4,
                                     day_length=day_length, horizon_days=horizon_days,
                                     df_times=df_times, df_jssp=df_jssp,
                                     df_execution=df_execution, df_undone=df_undone,
                                     df_plan=df_plan,
                                     notebook_prefix=notebook_prefix,
                                     rescheduler="sum_tardiness",
                                     solver_limit=solver_limit,
                                     plot_results=True
)
# Out:
# sum_tardiness_with_fixed_ops ...
#
# Solver-Informationen:
#   Zielfunktionswert       : 275300.9471
#   Solver-Status           : Optimal
#   Anzahl Variablen        : 29212
#   Anzahl Constraints      : 57515
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Für alle Jobs ist die Operationssequenz korrekt.
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
#
# [24:00:00] Job_017 started on M1
# [24:20:40] Job_001 started on M7
# [25:59:26] Job_001 finished on M7 (after 98 minutes 46 seconds)
# [25:59:26] Job_001 started on M8
# [26:17:57] Job_001 finished on M8 (after 18 minutes 31 seconds)
# [27:17:35] Job_017 finished on M1 (after 197 minutes 36 seconds)
# [28:06:36] Job_023 started on M2
# [28:21:13] Job_023 finished on M2 (after 14 minutes 37 seconds)
# [28:21:13] Job_023 started on M0
# [28:30:20] Job_023 finished on M0 (after 09 minutes 07 seconds)
# [28:30:20] Job_023 started on M1
# [28:45:16] Job_023 finished on M1 (after 14 minutes 55 seconds)
# [28:48:36] Job_018 started on M1
# [28:48:36] Job_023 started on M5
# [29:28:08] Job_018 finished on M1 (after 39 minutes 32 seconds)
# [29:35:17] Job_023 finished on M5 (after 46 minutes 41 seconds)
# [30:13:36] Job_025 started on M1
# [30:13:36] Job_018 started on M0
# [30:21:11] Job_018 finished on M0 (after 07 minutes 35 seconds)
# [30:26:36] Job_018 started on M2
# [30:40:33] Job_025 finished on M1 (after 26 minutes 57 seconds)
# [31:33:13] Job_018 finished on M2 (after 66 minutes 37 seconds)
# [31:33:13] Job_017 started on M2
# [31:33:13] Job_018 started on M6
# [31:38:52] Job_018 finished on M6 (after 05 minutes 40 seconds)
# [31:38:52] Job_018 started on M8
# [31:43:11] Job_017 finished on M2 (after 09 minutes 59 seconds)
# [31:43:11] Job_015 started on M2
# [31:43:11] Job_017 started on M3
# [31:56:36] Job_005 started on M0
# [31:58:08] Job_015 finished on M2 (after 14 minutes 56 seconds)
# [32:30:06] Job_017 finished on M3 (after 46 minutes 55 seconds)
# [32:57:13] Job_005 finished on M0 (after 60 minutes 37 seconds)
# [32:57:13] Job_015 started on M0
# [32:57:13] Job_005 started on M6
# [33:02:36] Job_015 finished on M0 (after 05 minutes 23 seconds)
# [33:02:36] Job_009 started on M0
# [33:05:43] Job_018 finished on M8 (after 86 minutes 51 seconds)
# [33:05:43] Job_018 started on M9
# [33:17:58] Job_009 finished on M0 (after 15 minutes 22 seconds)
# [33:17:58] Job_008 started on M0
# [33:17:58] Job_009 started on M2
# [33:51:59] Job_005 finished on M6 (after 54 minutes 47 seconds)
# [33:51:59] Job_005 started on M4
# [33:57:02] Job_018 finished on M9 (after 51 minutes 19 seconds)
# [33:59:19] Job_005 finished on M4 (after 07 minutes 20 seconds)
# [33:59:19] Job_017 started on M4
# [33:59:19] Job_005 started on M7
# [34:05:13] Job_009 finished on M2 (after 47 minutes 16 seconds)
# [34:10:57] Job_008 finished on M0 (after 52 minutes 59 seconds)
# [34:12:36] Job_003 started on M0
# [34:51:09] Job_005 finished on M7 (after 51 minutes 50 seconds)
# [35:03:33] Job_017 finished on M4 (after 64 minutes 14 seconds)
# [35:13:32] Job_003 finished on M0 (after 60 minutes 56 seconds)
# [35:23:36] Job_025 started on M0
# [36:17:14] Job_025 finished on M0 (after 53 minutes 38 seconds)
# [36:17:14] Job_025 started on M3
# [37:14:36] Job_024 started on M2
# [37:55:37] Job_025 finished on M3 (after 98 minutes 23 seconds)
# [37:55:37] Job_023 started on M3
# [38:15:05] Job_023 finished on M3 (after 19 minutes 28 seconds)
# [38:15:05] Job_023 started on M4
# [38:40:36] Job_015 started on M1
# [39:17:20] Job_023 finished on M4 (after 62 minutes 14 seconds)
# [39:22:19] Job_024 finished on M2 (after 127 minutes 43 seconds)
# [39:22:19] Job_025 started on M2
# [39:25:29] Job_015 finished on M1 (after 44 minutes 53 seconds)
# [39:25:29] Job_021 started on M1
# [39:32:36] Job_015 started on M5
# [39:34:39] Job_025 finished on M2 (after 12 minutes 20 seconds)
# [41:03:13] Job_015 finished on M5 (after 90 minutes 37 seconds)
# [41:03:13] Job_017 started on M5
# [41:03:13] Job_015 started on M3
# [41:08:00] Job_021 finished on M1 (after 102 minutes 31 seconds)
# [41:08:00] Job_024 started on M1
# [41:08:00] Job_021 started on M0
# [41:09:25] Job_017 finished on M5 (after 06 minutes 12 seconds)
# [41:09:25] Job_018 started on M5
# [41:09:25] Job_017 started on M6
# [41:11:39] Job_024 finished on M1 (after 03 minutes 39 seconds)
# [41:11:39] Job_008 started on M1
# [41:22:30] Job_015 finished on M3 (after 19 minutes 17 seconds)
# [41:22:30] Job_015 started on M4
# [41:58:05] Job_018 finished on M5 (after 48 minutes 40 seconds)
# [41:58:05] Job_024 started on M5
# [42:16:43] Job_015 finished on M4 (after 54 minutes 13 seconds)
# [42:26:26] Job_017 finished on M6 (after 77 minutes 01 second)
# [42:26:26] Job_009 started on M6
# [42:26:26] Job_017 started on M7
# [42:33:55] Job_009 finished on M6 (after 07 minutes 28 seconds)
# [42:33:55] Job_025 started on M6
# [42:33:55] Job_009 started on M8
# [42:37:28] Job_008 finished on M1 (after 85 minutes 49 seconds)
# [42:37:28] Job_008 started on M3
# [42:43:05] Job_024 finished on M5 (after 45 minutes)
# [42:53:58] Job_021 finished on M0 (after 105 minutes 58 seconds)
# [43:02:33] Job_025 finished on M6 (after 28 minutes 38 seconds)
# [43:13:08] Job_017 finished on M7 (after 46 minutes 42 seconds)
# [43:34:07] Job_008 finished on M3 (after 56 minutes 39 seconds)
# [43:34:07] Job_018 started on M3
# [44:16:31] Job_009 finished on M8 (after 102 minutes 37 seconds)
# [44:16:31] Job_023 started on M8
# [44:16:31] Job_009 started on M9
# [44:23:00] Job_018 finished on M3 (after 48 minutes 53 seconds)
# [44:23:00] Job_012 started on M3
# [44:23:00] Job_018 started on M4
# [44:54:56] Job_023 finished on M8 (after 38 minutes 25 seconds)
# [44:54:56] Job_015 started on M8
# [44:54:56] Job_023 started on M7
# [45:00:36] Job_008 started on M5
# [45:10:58] Job_015 finished on M8 (after 16 minutes 02 seconds)
# [45:10:58] Job_017 started on M8
# [45:27:36] Job_028 started on M1
# [45:37:53] Job_023 finished on M7 (after 42 minutes 56 seconds)
# [45:37:53] Job_015 started on M7
# [45:40:54] Job_017 finished on M8 (after 29 minutes 56 seconds)
# [46:02:03] Job_012 finished on M3 (after 99 minutes 04 seconds)
# [46:02:03] Job_024 started on M3
# [46:02:36] Job_008 finished on M5 (after 62 minutes)
# [46:02:36] Job_025 started on M5
# [46:02:36] Job_008 started on M2
# [46:18:09] Job_018 finished on M4 (after 115 minutes 09 seconds)
# [46:18:09] Job_003 started on M4
# [46:20:39] Job_015 finished on M7 (after 42 minutes 46 seconds)
# [46:20:39] Job_018 started on M7
# [46:36:15] Job_025 finished on M5 (after 33 minutes 38 seconds)
# [46:46:47] Job_009 finished on M9 (after 150 minutes 16 seconds)
# [46:46:47] Job_025 started on M9
# [46:46:47] Job_009 started on M5
# [46:58:53] Job_024 finished on M3 (after 56 minutes 50 seconds)
# [46:58:53] Job_021 started on M3
# [47:04:05] Job_028 finished on M1 (after 96 minutes 29 seconds)
# [47:04:05] Job_012 started on M1
# [47:07:09] Job_018 finished on M7 (after 46 minutes 30 seconds)
# [47:07:58] Job_003 finished on M4 (after 49 minutes 49 seconds)
# [47:07:58] Job_003 started on M6
# [47:15:02] Job_025 finished on M9 (after 28 minutes 14 seconds)
# [47:15:02] Job_023 started on M9
# [47:17:33] Job_003 finished on M6 (after 09 minutes 35 seconds)
# [47:17:33] Job_003 started on M8
# [47:22:40] Job_009 finished on M5 (after 35 minutes 53 seconds)
# [47:25:32] Job_012 finished on M1 (after 21 minutes 27 seconds)
# [47:36:36] Job_031 started on M0
# [47:41:23] Job_021 finished on M3 (after 42 minutes 30 seconds)
# [47:41:23] Job_009 started on M3
# [47:43:10] Job_008 finished on M2 (after 100 minutes 34 seconds)
# [47:43:10] Job_034 started on M2
# [47:55:54] Job_034 finished on M2 (after 12 minutes 43 seconds)
# [48:18:19] Job_031 finished on M0 (after 41 minutes 43 seconds)
# [48:18:19] Job_034 interrupted before machine M0 — would start too late (after 48:00:00)
# [48:19:36] Job_031 interrupted before machine M2 — would start too late (after 48:00:00)
# [48:20:14] Job_023 finished on M9 (after 65 minutes 13 seconds)
# [48:20:14] Job_017 interrupted before machine M9 — would start too late (after 48:00:00)
# [48:20:14] Job_015 interrupted before machine M9 — would start too late (after 48:00:00)
# [48:22:07] Job_009 finished on M3 (after 40 minutes 44 seconds)
# [48:22:07] Job_009 interrupted before machine M4 — would start too late (after 48:00:00)
# [48:22:50] Job_003 finished on M8 (after 65 minutes 17 seconds)
#
# [48:22:50] Simulation ended! There are no more active Operations
# sum_tardiness_with_fixed_ops ...
#
# Solver-Informationen:
#   Zielfunktionswert       : 1369464.5802
#   Solver-Status           : Optimal
#   Anzahl Variablen        : 40231
#   Anzahl Constraints      : 79383
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Für alle Jobs ist die Operationssequenz korrekt.
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
#
# [48:00:00] Job_032 started on M2
# [48:20:15] Job_017 started on M9
# [48:20:15] Job_023 started on M6
# [48:22:50] Job_025 started on M8
# [48:40:07] Job_017 finished on M9 (after 19 minutes 53 seconds)
# [48:41:15] Job_008 started on M9
# [48:53:55] Job_008 finished on M9 (after 12 minutes 41 seconds)
# [48:54:13] Job_032 finished on M2 (after 54 minutes 14 seconds)
# [49:27:17] Job_023 finished on M6 (after 67 minutes 02 seconds)
# [49:27:17] Job_008 started on M6
# [49:29:10] Job_025 finished on M8 (after 66 minutes 20 seconds)
# [49:51:50] Job_025 started on M7
# [50:01:32] Job_008 finished on M6 (after 34 minutes 15 seconds)
# [50:22:57] Job_025 finished on M7 (after 31 minutes 07 seconds)
# [50:22:57] Job_008 started on M7
# [50:22:57] Job_025 started on M4
# [50:32:46] Job_040 started on M1
# [51:09:05] Job_025 finished on M4 (after 46 minutes 08 seconds)
# [51:39:03] Job_008 finished on M7 (after 76 minutes 05 seconds)
# [51:50:50] Job_008 started on M4
# [52:02:59] Job_040 finished on M1 (after 90 minutes 13 seconds)
# [52:03:46] Job_032 started on M1
# [52:05:18] Job_032 finished on M1 (after 01 minute 31 seconds)
# [52:05:46] Job_032 started on M5
# [52:07:15] Job_008 finished on M4 (after 16 minutes 25 seconds)
# [52:16:50] Job_008 started on M8
# [52:49:55] Job_032 finished on M5 (after 44 minutes 08 seconds)
# [52:57:46] Job_032 started on M3
# [54:06:19] Job_008 finished on M8 (after 109 minutes 29 seconds)
# [55:17:50] Job_032 finished on M3 (after 140 minutes 04 seconds)
# [55:17:50] Job_032 started on M8
# [56:36:46] Job_032 finished on M8 (after 78 minutes 56 seconds)
# [56:36:46] Job_032 started on M9
# [57:40:07] Job_032 finished on M9 (after 63 minutes 21 seconds)
# [57:40:07] Job_032 started on M0
# [58:39:32] Job_032 finished on M0 (after 59 minutes 25 seconds)
# [58:39:32] Job_032 started on M6
# [59:36:46] Job_032 finished on M6 (after 57 minutes 14 seconds)
# [59:36:46] Job_032 started on M4
# [59:42:47] Job_032 finished on M4 (after 06 minutes 01 second)
# [59:42:47] Job_032 started on M7
# [60:15:29] Job_032 finished on M7 (after 32 minutes 42 seconds)
#
# [72:00:00]  Simulation ended! There are no active Operations.
# sum_tardiness_with_fixed_ops ...
#
# Solver-Informationen:
#   Zielfunktionswert       : 2368479.4764
#   Solver-Status           : Optimal
#   Anzahl Variablen        : 55294
#   Anzahl Constraints      : 109324
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Für alle Jobs ist die Operationssequenz korrekt.
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
#
# ⚠️ Kein Job startet innerhalb des Zeitfensters – Simulation wird abgebrochen.
# Nothing executed on day 3
# sum_tardiness_with_fixed_ops ...
#
# Solver-Informationen:
#   Zielfunktionswert       : 3072964.8926
#   Solver-Status           : Optimal
#   Anzahl Variablen        : 78314
#   Anzahl Constraints      : 155124
# ✅ Keine Maschinenkonflikte gefunden
# ✅ Für alle Jobs ist die Operationssequenz korrekt.
# ✅ Alle Operation starten erst nach Arrival des Job
# ✅ Zeitliche technologische Reihenfolge korrekt.
#
# ✅ Alle Constraints wurden erfüllt.
#
# ⚠️ Kein Job startet innerhalb des Zeitfensters – Simulation wird abgebrochen.
# Nothing executed on day 4
